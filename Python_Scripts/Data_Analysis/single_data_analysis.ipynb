# %% [markdown]
# Group all imports

# %%
import json
from datetime import datetime, time, timedelta
import os
from Powerfleet_APIs_Management import PowerFleetAPIsManager as ApiManager
from colorama import Fore, Style
import sys  # For printing caught exceptions
import re
from Powerfleet_APIs_Management import MongoDBConnector as DBConnector
from pathlib import Path
import pandas as pd
import csv
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import geopandas as gpd
import math

# %% [markdown]
# Enable plot UI backend

# %%
# %matplotlib tk

# %% [markdown]
# Update <u>PARAMETERS.json</u> with **current** date and time

# %%
file_path = "PARAMETERS.json" 

# Get the current date and time
current_datetime = datetime.now().strftime("%Y-%m-%d")  # Format as YYYY-MM-DD
current_time = datetime.now().strftime("%H:%M:%S")  # Format as HH:MM:SS

# Check if the file exists and is not empty
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' does not exist.")
    exit()

# Check if the file is empty
if os.path.getsize(file_path) == 0:
    print(f"Error: The file '{file_path}' is empty.")
    exit()

# Load the current JSON data
try:
    with open(file_path, "r") as file:
        data = json.load(file)
except json.JSONDecodeError as e:
    print(f"Error: Failed to decode JSON. Details: {e}")
    exit()

# Combine the date and time
combined_datetime = current_datetime + " " + current_time

# Update the 'endDate' field in the 'snapshot_api' section
data["snapshot_api"]["endDate"] = combined_datetime

# Save the updated JSON data back to the file
try:
    with open(file_path, "w") as file:
        json.dump(data, file, indent=4)  # Use indent for readable JSON formatting
    print(f"Updated PARAMETERS.json with: {combined_datetime}.")
except Exception as e:
    print(f"Error: Failed to save the updated file. Details: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 file_path = "PARAMETERS.json"
#       3 # Get the current date and time
# ----> 4 current_datetime = datetime.now().strftime("%Y-%m-%d")  # Format as YYYY-MM-DD
#       5 current_time = datetime.now().strftime("%H:%M:%S")  # Format as HH:MM:SS
#       7 # Check if the file exists and is not empty
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# <!-- Initialize **API** **managers** -->

# %%
print(Fore.YELLOW + f"MAIN CWD={os.getcwd()}")
print(f"MAIN, LISTDIR={os.listdir()}" + Style.RESET_ALL)

# Define the ApiParameterExtractor class
class ApiParameterExtractor:
    def __init__(self, json_file):
        with open(json_file, 'r') as file:
            self.parameters = json.load(file)

    def extract_parameters(self, api_type):
        # Normalize API type to lowercase
        api_type = api_type.lower()
        
        # Validate API type
        if api_type not in self.parameters:
            raise ValueError(f"Invalid API type: {api_type}. Valid types are 'live_api' or 'snapshot_api'.")
        
        # Return the corresponding dictionary for the given API type
        return self.parameters[api_type]


extractor = ApiParameterExtractor("PARAMETERS.json")

# Extract parameters for live_api and snapshot_api
live_api_params         = extractor.extract_parameters("live_api")
snapshot_api_params     = extractor.extract_parameters("snapshot_api")

# Pass the extracted parameters to PowerFleetAPIsManager
live_api_manager        = ApiManager(live_api_params)
snapshot_api_manager    = ApiManager(snapshot_api_params)
# Out:
# MAIN CWD=/home/georger/WorkDocuments/Sxoli/Ptyxiaki/Ptyxiaki-Repository/Python_Scripts/Data_Analysis
# MAIN, LISTDIR=['Powerfleet_APIs_Management.py', 'segment_1.csv', 'output.csv', 'single_data_analysis.ipynb', 'Plots', 'PARAMETERS.json', '__pycache__', 'tmp.csv', 'all_data_analysis.ipynb']

# %% [markdown]
# 1. Convert **JSON** to **CSV** so that **pandas** be able to use it
# 2. Convert a **UNIX timestamp column** to human-readable datetime format.
# 2. Create **csv** for every vehicle

# %%
CONVERT_UNIX_TO_DATE = False

# %%
# === Function to Save DataFrame to CSV ===
def save_to_csv(dataframe, output_dir, file_name):
    """
    Save a DataFrame to a specified CSV file in the given directory.
    
    :param dataframe: The DataFrame to save.
    :param output_dir: The directory where the CSV file will be saved.
    :param file_name: The name of the CSV file (e.g., "file_name.csv").
    """
    if not dataframe.empty:  # Only save if the DataFrame is not empty
        os.makedirs(output_dir, exist_ok=True)  # Ensure the directory exists
        file_path = Path(output_dir) / file_name  # Construct the full file path
        dataframe.to_csv(file_path, index=False)  # Save the DataFrame to CSV
        print(f"Data saved to {file_path}")
    else:
        print(f"No data to save for {file_name}. Skipping...")

# === Function to Convert UNIX Timestamps to Datetime Using Pandas ===
def unix_to_datetime_pandas(dataframe, column_name):
    """
    Convert a UNIX timestamp column to human-readable datetime format.
    
    :param dataframe: The DataFrame containing the column.
    :param column_name: The column name containing UNIX timestamps.
    """
    if column_name in dataframe.columns:
        try:
            dataframe[column_name] = pd.to_datetime(dataframe[column_name] / 1000, unit='s')  # Convert from ms to seconds
            print(f"Converted '{column_name}' to human-readable datetime.")
        except Exception as e:
            print(f"Error converting column '{column_name}': {e}")
    else:
        print(f"Column '{column_name}' not found in DataFrame.")

# === Constants ===
target_file = "../../DataSets/API_Responses/Vehicle_Data/Every_vehicle_response.csv"
snapshot_csv_path = "../../DataSets/API_Responses/Snapshot_API_Response_data_set.csv"  # Modify with your source CSV path

# === Step 1: Read Headers from the Source File ===
with open(snapshot_csv_path, mode="r") as infile:
    reader = csv.reader(infile)
    headers = next(reader)  # Extract headers from the source file

# === Step 2: Write Headers to the Target File ===
with open(target_file, mode="w", newline="") as outfile:
    writer = csv.writer(outfile)
    writer.writerow(headers)  # Write the headers into the target file

# === Step 3: Load Parameters from JSON File ===
with open("PARAMETERS.json", "r") as file:
    PARAMETERS = json.load(file)  # Load API parameters from the JSON file

# === Step 4: Loop to Fetch and Append Data for Each Vehicle ===
_cnt = 1  # Counter for vehicle IDs
snapshot_data = None  # Initialize snapshot_data to enter the loop

while _cnt <= 20:  # Run for up to 100 times
    # Update the vehicleId in PARAMETERS
    PARAMETERS["snapshot_api"]["vehicleId"] = str(_cnt)
    
    # Extract updated vehicleId and fetch snapshot data
    vehicleId = PARAMETERS["snapshot_api"]["vehicleId"]
    startDate = PARAMETERS["snapshot_api"]["startDate"]
    endDate = PARAMETERS["snapshot_api"]["endDate"]
    
    # Fetch snapshot data (Returns JSON)
    snapshot_data = snapshot_api_manager.get_snapshot_data(vehicleId, startDate, endDate)
    
    # Skip if no data is found (None or empty data)
    if not snapshot_data:
        print(f"No data found for vehicleId {vehicleId}. Skipping...")
        _cnt += 1
        continue
    
    # Parse the JSON snapshot data into a DataFrame
    try:
        # If the snapshot data is a valid JSON string, parse it
        snapshot_data_dict = json.loads(snapshot_data) if isinstance(snapshot_data, str) else snapshot_data
        
        # Handle JSON structure (either dict or list)
        if isinstance(snapshot_data_dict, dict):
            snapshot_data_list = [snapshot_data_dict]  # Convert single dict to list of dicts
        elif isinstance(snapshot_data_dict, list):
            snapshot_data_list = snapshot_data_dict  # Already a list of dicts
        else:
            snapshot_data_list = []
        
        # Create a DataFrame from the list of dictionaries
        snapshot_df = pd.DataFrame(snapshot_data_list)
        
        # Convert UNIX timestamps in 'dateStored' column to human-readable format
        if CONVERT_UNIX_TO_DATE != False:
            unix_to_datetime_pandas(snapshot_df, 'dateStored')
        
        # Save the DataFrame to CSV only if it's not empty
        save_to_csv(snapshot_df, "../../DataSets/API_Responses/Vehicle_Data", f"Vehicle_{_cnt}_response.csv")
    
    except json.JSONDecodeError as e:
        print(f"Error decoding snapshot JSON for vehicleId {_cnt}: {e}")

    # Increment the vehicleId counter
    _cnt += 1

print("Process complete!")
# Out:
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_1_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_2_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_3_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_4_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_5_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_6_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_7_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_8_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_9_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_10_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_11_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_12_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_13_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_14_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_15_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_16_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_17_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_18_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_19_response.csv
# **Snapshot API**
# Snapshot API Request Successful!
# Data saved to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_20_response.csv
# Process complete!

# %% [markdown]
# Visualize data **dispersion**

# %% [markdown]
# 1) Plot **unique** vehicles

# %%
# Path to the folder containing the CSV files
folder_path = "../../DataSets/API_Responses/Vehicle_Data/"  # Modify with your folder path

# Initialize an empty dictionary to store vehicleId (as an integer for sorting) and its corresponding row count
vehicle_lines = {}

# Loop through the files in the folder
for file_name in os.listdir(folder_path):
    # Check if the file is a CSV file and starts with "Vehicle_"
    if file_name.endswith(".csv") and file_name.startswith("Vehicle_"):
        # Extract the vehicleId from the file name (assuming the naming convention is 'Vehicle_<id>.csv')
        vehicle_id_str = file_name.split('_')[1].split('.')[0]  # Extract the part after "Vehicle_" and before ".csv"
        
        # Ensure vehicle_id is numeric; if not, skip the file
        try:
            vehicle_id = int(vehicle_id_str)  # Convert to integer for proper sorting
        except ValueError:
            print(f"Skipping file with non-numeric Vehicle ID: {file_name}")
            continue

        # Construct the full path to the file
        file_path = os.path.join(folder_path, file_name)
        print(file_path)
        
        # Read the CSV file to count the number of rows (excluding the header)
        try:
            df = pd.read_csv(file_path)
            vehicle_lines[vehicle_id] = len(df)  # Store the line count for each vehicleId
        except Exception as e:
            print(Fore.RED + f"Error reading {file_name}: {e}" + Style.RESET_ALL)

# Sort the dictionary by vehicleId (numerically in ascending order)
sorted_vehicle_lines = dict(sorted(vehicle_lines.items()))

# Convert the sorted dictionary to two lists for plotting
vehicle_ids = list(sorted_vehicle_lines.keys())
line_counts = list(sorted_vehicle_lines.values())

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(vehicle_ids, line_counts, color='skyblue')
plt.xlabel('Vehicle ID')
plt.ylabel('Number of Lines')
plt.title(f'Number of Lines per Vehicle ID from ({PARAMETERS["snapshot_api"]["startDate"]}) to ({PARAMETERS["snapshot_api"]["endDate"]})')
plt.xticks(vehicle_ids)  # Rotate vehicle IDs if needed
plt.tight_layout()
plt.grid()

# Set a logarithmic scale for better visualization of large variations
plt.yscale("log")

# Show and save the plot

plt.show()
# Out:
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_2_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_3_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_19_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_11_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_16_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_6_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_18_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_17_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_9_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_20_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_14_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_1_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_15_response_formatted.csv
# Error reading Vehicle_15_response_formatted.csv: No columns to parse from file
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_12_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_4_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_10_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_5_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_8_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_15_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_7_response.csv
# ../../DataSets/API_Responses/Vehicle_Data/Vehicle_13_response.csv

# %% [markdown]
# 2) Create 2 columns for datetime readable for Humans and for time alone

# %%
# Load the CSV file into a DataFrame
VEHICLE_15_PATH = "../../DataSets/API_Responses/Vehicle_Data/Vehicle_15_response.csv"
df = pd.read_csv(VEHICLE_15_PATH)

# Convert the 'dateStored' column to datetime format
df['dateStoredHuman']       = df['dateStored'].apply(lambda x: datetime.fromtimestamp(x / 1000))
df['dateOnlyStoredHuman']   = df['dateStoredHuman'].dt.date  # Extract the date only
df['timeOnly']              = df['dateStoredHuman'].dt.time  # Extract the time only

# Sort the DataFrame by 'dateStored' in ascending order
DATA_SORTED                 = df.sort_values(by='dateStored', ascending=True)

# Extract columns of interest
lat_clmn                    = DATA_SORTED['lat']
long_clmn                   = DATA_SORTED['lng']
date_stored                 = DATA_SORTED['dateStored']

#! Drop temp columns
df = df.drop(columns=['dateStoredHuman'])


# Save the modified DataFrame back to the CSV
df.to_csv(VEHICLE_15_PATH, index=False)

# Check the first few rows of the sorted data
print(DATA_SORTED.head())
# Out:
#    vehicleId        lat        lng     dateStored  velocity  odometer  \
# 0         15  38.034933  23.748265  1716383302000       0.0       0.0
# 1         15  38.034833  23.747995  1716383303000       1.0       0.0
# 2         15  38.034692  23.748035  1716383339000       0.0       0.0
# 3         15  38.034720  23.748038  1716383716000       8.0       0.0
# 4         15  38.034725  23.748063  1716383722000       6.0       0.0
#
#    engineVoltage     dateStoredHuman dateOnlyStoredHuman  timeOnly
# 0            0.0 2024-05-22 16:08:22          2024-05-22  16:08:22
# 1            0.0 2024-05-22 16:08:23          2024-05-22  16:08:23
# 2            0.0 2024-05-22 16:08:59          2024-05-22  16:08:59
# 3            0.0 2024-05-22 16:15:16          2024-05-22  16:15:16
# 4            0.0 2024-05-22 16:15:22          2024-05-22  16:15:22

# %%
plt.figure(figsize=(30, 20))
# plt.title(f'from {date_stored.iloc[0].strftime("%Y-%m-%d")} to {date_stored.iloc[-1].strftime("%Y-%m-%d")}')
plt.xlabel('Latitude')
plt.ylabel('Longitude')


# Turn off offset notation
plt.gca().ticklabel_format(useOffset=False)

plt.grid()
plt.scatter(lat_clmn, long_clmn)
plt.plot(lat_clmn, long_clmn, color='r')

plt.show()

# %% [markdown]
# Plot all trips of current vehicle

# %%
plt.plot(range(len(df['dateStored'])), df['dateStored'])

plt.show()

# %% [markdown]
# Plot velocity

# %%
plt.figure(figsize=(30, 20))
plt.plot(df['velocity'], marker='o', linestyle='-', color='b')
plt.title('Velocity Plot')
plt.xlabel('Index')
plt.ylabel('Velocity')
plt.grid(True)

plt.show()

# %%
merged_df

# %% [markdown]
# - Calculate which the **30 degrees turns** on coordinatess
# - Plot the **30 degrees turns** vs velocities **before and after** making the turn
#
# | Decimal Places | Latitude Precision (meters) | Longitude Precision (meters at Equator) |
# |----------------|-----------------------------|-----------------------------------------|
# | 1              | ~11,132 m                   | ~11,132 m                               |
# | 2              | ~1,113 m                    | ~1,113 m                                |
# | 3              | ~111.3 m                    | ~111.3 m                                |
# | 4              | ~11.13 m                    | ~11.13 m                                |
# | 5              | ~1.113 m                    | ~1.113 m                                |
# | 6              | ~0.1113 m                   | ~0.1113 m                               |
# | 7              | ~0.01113 m                  | ~0.01113 m                              |
# | 8              | ~0.001113 m                 | ~0.001113 m                             |

# %%
def process_coordinates(DATA_SORTED):
    # Load the dataset into a GeoDataFrame
    gdf = gpd.GeoDataFrame(DATA_SORTED, geometry=gpd.points_from_xy(DATA_SORTED['lng'], DATA_SORTED['lat']))

    # Function to calculate precision correspondences
    def calculate_precision_distances():
        precision_list = []
        for decimals in range(1, 9):  # For 1 to 8 decimals
            latitude_precision = 111_320 / (10**decimals)  # Latitude: meters
            longitude_precision = latitude_precision  # Assuming equator (lat = 0)
            precision_list.append((decimals, latitude_precision, longitude_precision))
        return precision_list

    # Calculate precision distances
    precisions = calculate_precision_distances()

    # Create a DataFrame for output
    precision_df = pd.DataFrame(precisions, columns=['Decimal Places', 'Latitude Precision (m)', 'Longitude Precision (m)'])
    # print(precision_df)

    # Function to calculate the bearing between two points
    def calculate_bearing(lat1, lon1, lat2, lon2):
        """
        Calculate the bearing between two points.
        Returns the bearing in degrees.
        """
        lat1_rad, lon1_rad = math.radians(lat1), math.radians(lon1)
        lat2_rad, lon2_rad = math.radians(lat2), math.radians(lon2)

        delta_lon = lon2_rad - lon1_rad
        x = math.sin(delta_lon) * math.cos(lat2_rad)
        y = math.cos(lat1_rad) * math.sin(lat2_rad) - math.sin(lat1_rad) * math.cos(lat2_rad) * math.cos(delta_lon)
        bearing = math.atan2(x, y)
        bearing_degrees = (math.degrees(bearing) + 360) % 360  # Normalize to 0-360
        return bearing_degrees

    # Function to get orientation from bearing
    def get_orientation(bearing):
        """
        Convert a bearing in degrees to a cardinal direction.
        """
        directions = ['North', 'Northeast', 'East', 'Southeast', 'South', 'Southwest', 'West', 'Northwest']
        idx = round(bearing / 45) % 8  # Divide by 45 degrees for 8 cardinal directions
        return directions[idx]

    # Function to get the latest and next coordinate
    def get_latest_and_next_coordinates(gdf):
        latest_coordinate = gdf.iloc[-1]  # The last entry is the latest coordinate
        # print("Latest coordinate:", latest_coordinate)

        # Get next coordinates and calculate bearings
        next_coordinates = []
        for idx in range(len(gdf) - 1):
            current_row = gdf.iloc[idx]
            next_row = gdf.iloc[idx + 1]
            bearing = calculate_bearing(current_row['lat'], current_row['lng'], next_row['lat'], next_row['lng'])
            orientation = get_orientation(bearing)
            next_coordinates.append((current_row['lat'], current_row['lng'], next_row['lat'], next_row['lng'], bearing, orientation))
        
        return latest_coordinate, next_coordinates

    # Get the latest and next coordinates
    latest_coordinate, next_coordinates = get_latest_and_next_coordinates(gdf)

    # Print the results
    print("\nLatest Coordinate:")
    print(latest_coordinate[['lat', 'lng']])

    print("\nNext Coordinates with Orientation:")
    for coord in next_coordinates:
        print(f"Current: ({coord[0]}, {coord[1]}) -> Next: ({coord[2]}, {coord[3]}) | Bearing: {coord[4]:.2f}° | Orientation: {coord[5]}")

    return latest_coordinate, next_coordinates


# Assuming 'DATA_SORTED' is already defined as a DataFrame with columns 'lat' and 'lng'
latest_coordinate, next_coordinates = process_coordinates(DATA_SORTED)
# Out:
# Latest Coordinate:
# lat    38.050772
# lng    23.761143
# Name: 10394, dtype: object
#
# Next Coordinates with Orientation:
# Current: (38.0349333, 23.7482649) -> Next: (38.0348333, 23.747995) | Bearing: 244.81° | Orientation: Southwest
# Current: (38.0348333, 23.747995) -> Next: (38.0346916, 23.7480349) | Bearing: 167.50° | Orientation: South
# Current: (38.0346916, 23.7480349) -> Next: (38.03472, 23.7480383) | Bearing: 5.39° | Orientation: North
# Current: (38.03472, 23.7480383) -> Next: (38.034725, 23.7480633) | Bearing: 75.75° | Orientation: East
# Current: (38.034725, 23.7480633) -> Next: (38.0348666, 23.7479199) | Bearing: 321.42° | Orientation: Northwest
# Current: (38.0348666, 23.7479199) -> Next: (38.0349916, 23.7477399) | Bearing: 311.40° | Orientation: Northwest
# Current: (38.0349916, 23.7477399) -> Next: (38.0351233, 23.7475533) | Bearing: 311.86° | Orientation: Northwest
# Current: (38.0351233, 23.7475533) -> Next: (38.0351266, 23.7475233) | Bearing: 277.95° | Orientation: West
# Current: (38.0351266, 23.7475233) -> Next: (38.0349166, 23.7477833) | Bearing: 135.72° | Orientation: Southeast
# Current: (38.0349166, 23.7477833) -> Next: (38.0346599, 23.7480866) | Bearing: 137.06° | Orientation: Southeast
# Current: (38.0346599, 23.7480866) -> Next: (38.0346283, 23.7481549) | Bearing: 120.43° | Orientation: Southeast
# Current: (38.0346283, 23.7481549) -> Next: (38.0342816, 23.7485333) | Bearing: 139.32° | Orientation: Southeast
# Current: (38.0342816, 23.7485333) -> Next: (38.0343533, 23.7484883) | Bearing: 333.70° | Orientation: Northwest
# Current: (38.0343533, 23.7484883) -> Next: (38.0344849, 23.7483283) | Bearing: 316.24° | Orientation: Northwest
# Current: (38.0344849, 23.7483283) -> Next: (38.0344816, 23.7483766) | Bearing: 94.96° | Orientation: East
# Current: (38.0344816, 23.7483766) -> Next: (38.0345216, 23.7483566) | Bearing: 338.50° | Orientation: North
# Current: (38.0345216, 23.7483566) -> Next: (38.0346633, 23.7481816) | Bearing: 315.79° | Orientation: Northwest
# Current: (38.0346633, 23.7481816) -> Next: (38.0346733, 23.7481233) | Bearing: 282.29° | Orientation: West
# Current: (38.0346733, 23.7481233) -> Next: (38.0343783, 23.7483716) | Bearing: 146.46° | Orientation: Southeast
# Current: (38.0343783, 23.7483716) -> Next: (38.034235, 23.7485783) | Bearing: 131.35° | Orientation: Southeast
# Current: (38.034235, 23.7485783) -> Next: (38.0343016, 23.7486399) | Bearing: 36.07° | Orientation: Northeast
# Current: (38.0343016, 23.7486399) -> Next: (38.0344683, 23.748475) | Bearing: 322.08° | Orientation: Northwest
# Current: (38.0344683, 23.748475) -> Next: (38.034635, 23.7483633) | Bearing: 332.18° | Orientation: Northwest
# Current: (38.034635, 23.7483633) -> Next: (38.0347666, 23.7482066) | Bearing: 316.84° | Orientation: Northwest
# Current: (38.0347666, 23.7482066) -> Next: (38.0347183, 23.7480133) | Bearing: 252.40° | Orientation: West
# Current: (38.0347183, 23.7480133) -> Next: (38.034855, 23.7478133) | Bearing: 310.95° | Orientation: Northwest
# Current: (38.034855, 23.7478133) -> Next: (38.0350133, 23.7476833) | Bearing: 327.10° | Orientation: Northwest
# Current: (38.0350133, 23.7476833) -> Next: (38.0350383, 23.7476283) | Bearing: 299.99° | Orientation: Northwest
# Current: (38.0350383, 23.7476283) -> Next: (38.0337599, 23.749865) | Bearing: 125.97° | Orientation: Southeast
# Current: (38.0337599, 23.749865) -> Next: (38.0338383, 23.7496316) | Bearing: 293.10° | Orientation: Northwest
# Current: (38.0338383, 23.7496316) -> Next: (38.0339583, 23.7494099) | Bearing: 304.50° | Orientation: Northwest
# Current: (38.0339583, 23.7494099) -> Next: (38.0340366, 23.7493183) | Bearing: 317.34° | Orientation: Northwest
# Current: (38.0340366, 23.7493183) -> Next: (38.0341566, 23.74919) | Bearing: 319.90° | Orientation: Northwest
# Current: (38.0341566, 23.74919) -> Next: (38.0341916, 23.7490766) | Bearing: 291.40° | Orientation: West
# Current: (38.0341916, 23.7490766) -> Next: (38.0342366, 23.7487699) | Bearing: 280.55° | Orientation: West
# Current: (38.0342366, 23.7487699) -> Next: (38.0342883, 23.7485233) | Bearing: 284.91° | Orientation: West
# Current: (38.0342883, 23.7485233) -> Next: (38.0340666, 23.74858) | Bearing: 168.61° | Orientation: South
# Current: (38.0340666, 23.74858) -> Next: (38.0341933, 23.7484066) | Bearing: 312.85° | Orientation: Northwest
# Current: (38.0341933, 23.7484066) -> Next: (38.0342316, 23.7483866) | Bearing: 337.64° | Orientation: North
# Current: (38.0342316, 23.7483866) -> Next: (38.0343233, 23.7483183) | Bearing: 329.60° | Orientation: Northwest
# Current: (38.0343233, 23.7483183) -> Next: (38.0343033, 23.7484149) | Bearing: 104.73° | Orientation: East
# Current: (38.0343033, 23.7484149) -> Next: (38.0348716, 23.74776) | Bearing: 317.77° | Orientation: Northwest
# Current: (38.0348716, 23.74776) -> Next: (38.0348116, 23.747865) | Bearing: 125.96° | Orientation: Southeast
# Current: (38.0348116, 23.747865) -> Next: (38.0347733, 23.7479866) | Bearing: 111.80° | Orientation: East
# Current: (38.0347733, 23.7479866) -> Next: (38.0346816, 23.7480283) | Bearing: 160.29° | Orientation: South
# Current: (38.0346816, 23.7480283) -> Next: (38.0346166, 23.7481066) | Bearing: 136.50° | Orientation: Southeast
# Current: (38.0346166, 23.7481066) -> Next: (38.0348833, 23.7478633) | Bearing: 324.30° | Orientation: Northwest
# Current: (38.0348833, 23.7478633) -> Next: (38.0347416, 23.7480283) | Bearing: 137.47° | Orientation: Southeast
# Current: (38.0347416, 23.7480283) -> Next: (38.0347283, 23.7480816) | Bearing: 107.58° | Orientation: East
# Current: (38.0347283, 23.7480816) -> Next: (38.0345333, 23.7482716) | Bearing: 142.50° | Orientation: Southeast
# Current: (38.0345333, 23.7482716) -> Next: (38.0346866, 23.7482016) | Bearing: 340.22° | Orientation: North
# Current: (38.0346866, 23.7482016) -> Next: (38.0346766, 23.7480433) | Bearing: 265.41° | Orientation: West
# Current: (38.0346766, 23.7480433) -> Next: (38.03474, 23.7479716) | Bearing: 318.31° | Orientation: Northwest
# Current: (38.03474, 23.7479716) -> Next: (38.03475, 23.747935) | Bearing: 289.13° | Orientation: West
# Current: (38.03475, 23.747935) -> Next: (38.03478, 23.7479083) | Bearing: 324.97° | Orientation: Northwest
# Current: (38.03478, 23.7479083) -> Next: (38.0349033, 23.7477933) | Bearing: 323.70° | Orientation: Northwest
# Current: (38.0349033, 23.7477933) -> Next: (38.0351166, 23.7477183) | Bearing: 344.52° | Orientation: North
# Current: (38.0351166, 23.7477183) -> Next: (38.035005, 23.74752) | Bearing: 234.45° | Orientation: Southwest
# Current: (38.035005, 23.74752) -> Next: (37.5107499, 22.3862716) | Bearing: 244.44° | Orientation: Southwest
# Current: (37.5107499, 22.3862716) -> Next: (37.5108233, 22.385855) | Bearing: 282.52° | Orientation: West
# Current: (37.5108233, 22.385855) -> Next: (37.5108716, 22.3856133) | Bearing: 284.14° | Orientation: West
# Current: (37.5108716, 22.3856133) -> Next: (37.5108583, 22.385625) | Bearing: 145.09° | Orientation: Southeast
# Current: (37.5108583, 22.385625) -> Next: (37.5108483, 22.3853816) | Bearing: 267.04° | Orientation: West
# Current: (37.5108483, 22.3853816) -> Next: (37.510865, 22.385315) | Bearing: 287.54° | Orientation: West
# Current: (37.510865, 22.385315) -> Next: (37.510935, 22.38654) | Bearing: 85.88° | Orientation: East
# Current: (37.510935, 22.38654) -> Next: (37.510885, 22.3865099) | Bearing: 205.53° | Orientation: Southwest
# Current: (37.510885, 22.3865099) -> Next: (37.51083, 22.3865483) | Bearing: 151.02° | Orientation: Southeast
# Current: (37.51083, 22.3865483) -> Next: (37.5108349, 22.386535) | Bearing: 294.91° | Orientation: Northwest
# Current: (37.5108349, 22.386535) -> Next: (37.510845, 22.3862916) | Bearing: 272.99° | Orientation: West
# Current: (37.510845, 22.3862916) -> Next: (37.51076, 22.386025) | Bearing: 248.10° | Orientation: West
# Current: (37.51076, 22.386025) -> Next: (37.51064, 22.3858216) | Bearing: 233.36° | Orientation: Southwest
# Current: (37.51064, 22.3858216) -> Next: (37.5103233, 22.3870316) | Bearing: 108.26° | Orientation: East
# Current: (37.5103233, 22.3870316) -> Next: (37.5103249, 22.3867733) | Bearing: 270.45° | Orientation: West
# Current: (37.5103249, 22.3867733) -> Next: (37.5104983, 22.3864733) | Bearing: 306.08° | Orientation: Northwest
# Current: (37.5104983, 22.3864733) -> Next: (37.51059, 22.3862716) | Bearing: 299.82° | Orientation: Northwest
# Current: (37.51059, 22.3862716) -> Next: (37.5104816, 22.3866183) | Bearing: 111.51° | Orientation: East
# Current: (37.5104816, 22.3866183) -> Next: (37.51041, 22.38668) | Bearing: 145.64° | Orientation: Southeast
# Current: (37.51041, 22.38668) -> Next: (37.511205, 22.3858416) | Bearing: 320.09° | Orientation: Northwest
# Current: (37.511205, 22.3858416) -> Next: (37.5112483, 22.3855916) | Bearing: 282.32° | Orientation: West
# Current: (37.5112483, 22.3855916) -> Next: (37.51135, 22.3853399) | Bearing: 296.99° | Orientation: Northwest
# Current: (37.51135, 22.3853399) -> Next: (37.5112183, 22.3854733) | Bearing: 141.22° | Orientation: Southeast
# Current: (37.5112183, 22.3854733) -> Next: (37.5112233, 22.3854916) | Bearing: 70.99° | Orientation: East
# Current: (37.5112233, 22.3854916) -> Next: (37.5112033, 22.3856383) | Bearing: 99.75° | Orientation: East
# Current: (37.5112033, 22.3856383) -> Next: (37.5111766, 22.3856716) | Bearing: 135.31° | Orientation: Southeast
# Current: (37.5111766, 22.3856716) -> Next: (37.510875, 22.3852) | Bearing: 231.12° | Orientation: Southwest
# Current: (37.510875, 22.3852) -> Next: (37.5108816, 22.3851783) | Bearing: 290.98° | Orientation: West
# Current: (37.5108816, 22.3851783) -> Next: (37.51077, 22.3861833) | Bearing: 97.97° | Orientation: East
# Current: (37.51077, 22.3861833) -> Next: (37.5107133, 22.3859416) | Bearing: 253.53° | Orientation: West
# Current: (37.5107133, 22.3859416) -> Next: (37.5107333, 22.3857116) | Bearing: 276.26° | Orientation: West
# Current: (37.5107333, 22.3857116) -> Next: (37.5108083, 22.3858583) | Bearing: 57.20° | Orientation: Northeast
# Current: (37.5108083, 22.3858583) -> Next: (37.5108366, 22.38559) | Bearing: 277.57° | Orientation: West
# Current: (37.5108366, 22.38559) -> Next: (37.5107616, 22.3853099) | Bearing: 251.35° | Orientation: West
# Current: (37.5107616, 22.3853099) -> Next: (37.51062, 22.3850533) | Bearing: 235.17° | Orientation: Southwest
# Current: (37.51062, 22.3850533) -> Next: (37.5105583, 22.384815) | Bearing: 251.92° | Orientation: West
# Current: (37.5105583, 22.384815) -> Next: (37.51048, 22.3845616) | Bearing: 248.72° | Orientation: West
# Current: (37.51048, 22.3845616) -> Next: (37.5103316, 22.3843399) | Bearing: 229.84° | Orientation: Southwest
# Current: (37.5103316, 22.3843399) -> Next: (37.510805, 22.3862116) | Bearing: 72.31° | Orientation: East
# Current: (37.510805, 22.3862116) -> Next: (37.5108066, 22.3862016) | Bearing: 281.40° | Orientation: West
# Current: (37.5108066, 22.3862016) -> Next: (37.5107583, 22.38643) | Bearing: 104.93° | Orientation: East
# Current: (37.5107583, 22.38643) -> Next: (37.510725, 22.3865066) | Bearing: 118.72° | Orientation: Southeast
# Current: (37.510725, 22.3865066) -> Next: (37.5107733, 22.3862683) | Bearing: 284.33° | Orientation: West
# Current: (37.5107733, 22.3862683) -> Next: (37.5108316, 22.3860466) | Bearing: 288.34° | Orientation: West
# Current: (37.5108316, 22.3860466) -> Next: (37.5108866, 22.3858216) | Bearing: 287.13° | Orientation: West
# Current: (37.5108866, 22.3858216) -> Next: (37.51087, 22.3857466) | Bearing: 254.41° | Orientation: West
# Current: (37.51087, 22.3857466) -> Next: (37.5109283, 22.3859483) | Bearing: 69.98° | Orientation: East
# Current: (37.5109283, 22.3859483) -> Next: (37.51096, 22.385855) | Bearing: 293.19° | Orientation: Northwest
# Current: (37.51096, 22.385855) -> Next: (37.5109716, 22.385605) | Bearing: 273.35° | Orientation: West
# Current: (37.5109716, 22.385605) -> Next: (37.510995, 22.3853766) | Bearing: 277.36° | Orientation: West
# Current: (37.510995, 22.3853766) -> Next: (37.5110616, 22.3851133) | Bearing: 287.69° | Orientation: West
# Current: (37.5110616, 22.3851133) -> Next: (37.5111149, 22.3848316) | Bearing: 283.42° | Orientation: West
# Current: (37.5111149, 22.3848316) -> Next: (37.5111933, 22.38465) | Bearing: 298.56° | Orientation: Northwest
# Current: (37.5111933, 22.38465) -> Next: (37.510935, 22.3868166) | Bearing: 98.55° | Orientation: East
# Current: (37.510935, 22.3868166) -> Next: (37.51097, 22.3865583) | Bearing: 279.69° | Orientation: West
# Current: (37.51097, 22.3865583) -> Next: (37.511005, 22.3863299) | Bearing: 280.93° | Orientation: West
# Current: (37.511005, 22.3863299) -> Next: (37.5109866, 22.3863266) | Bearing: 188.10° | Orientation: South
# Current: (37.5109866, 22.3863266) -> Next: (37.510505, 22.3857566) | Bearing: 223.19° | Orientation: Southwest
# Current: (37.510505, 22.3857566) -> Next: (37.5104783, 22.3852833) | Bearing: 265.93° | Orientation: West
# Current: (37.5104783, 22.3852833) -> Next: (37.5104916, 22.3851083) | Bearing: 275.47° | Orientation: West
# Current: (37.5104916, 22.3851083) -> Next: (37.5113749, 22.3858349) | Bearing: 33.12° | Orientation: Northeast
# Current: (37.5113749, 22.3858349) -> Next: (37.51155, 22.3857) | Bearing: 328.57° | Orientation: Northwest
# Current: (37.51155, 22.3857) -> Next: (37.51159, 22.3856883) | Bearing: 346.94° | Orientation: North
# Current: (37.51159, 22.3856883) -> Next: (37.5112616, 22.3859616) | Bearing: 146.57° | Orientation: Southeast
# Current: (37.5112616, 22.3859616) -> Next: (37.5112566, 22.3858766) | Bearing: 265.76° | Orientation: West
# Current: (37.5112566, 22.3858766) -> Next: (37.511265, 22.3858783) | Bearing: 9.12° | Orientation: North
# Current: (37.511265, 22.3858783) -> Next: (37.5114083, 22.3856433) | Bearing: 307.55° | Orientation: Northwest
# Current: (37.5114083, 22.3856433) -> Next: (37.5114266, 22.3853699) | Bearing: 274.82° | Orientation: West
# Current: (37.5114266, 22.3853699) -> Next: (37.5116916, 22.3852249) | Bearing: 336.54° | Orientation: Northwest
# Current: (37.5116916, 22.3852249) -> Next: (37.5119166, 22.3851116) | Bearing: 338.23° | Orientation: North
# Current: (37.5119166, 22.3851116) -> Next: (37.5120283, 22.3850233) | Bearing: 327.91° | Orientation: Northwest
# Current: (37.5120283, 22.3850233) -> Next: (37.5109216, 22.386295) | Bearing: 137.65° | Orientation: Southeast
# Current: (37.5109216, 22.386295) -> Next: (37.5109283, 22.3862616) | Bearing: 284.19° | Orientation: West
# Current: (37.5109283, 22.3862616) -> Next: (37.51107, 22.386215) | Bearing: 345.38° | Orientation: North
# Current: (37.51107, 22.386215) -> Next: (37.5112249, 22.3859983) | Bearing: 312.02° | Orientation: Northwest
# Current: (37.5112249, 22.3859983) -> Next: (37.5113583, 22.3857883) | Bearing: 308.69° | Orientation: Northwest
# Current: (37.5113583, 22.3857883) -> Next: (37.5114833, 22.3855283) | Bearing: 301.22° | Orientation: Northwest
# Current: (37.5114833, 22.3855283) -> Next: (37.5115866, 22.3852933) | Bearing: 298.99° | Orientation: Northwest
# Current: (37.5115866, 22.3852933) -> Next: (37.5116883, 22.385055) | Bearing: 298.28° | Orientation: Northwest
# Current: (37.5116883, 22.385055) -> Next: (37.5116883, 22.385055) | Bearing: 0.00° | Orientation: North
# Current: (37.5116883, 22.385055) -> Next: (37.5110266, 22.3860516) | Bearing: 129.93° | Orientation: Southeast
# Current: (37.5110266, 22.3860516) -> Next: (37.511265, 22.3852199) | Bearing: 289.87° | Orientation: West
# Current: (37.511265, 22.3852199) -> Next: (37.5112383, 22.385335) | Bearing: 106.30° | Orientation: East
# Current: (37.5112383, 22.385335) -> Next: (37.5107349, 22.385935) | Bearing: 136.61° | Orientation: Southeast
# Current: (37.5107349, 22.385935) -> Next: (37.5107583, 22.3856916) | Bearing: 276.91° | Orientation: West
# Current: (37.5107583, 22.3856916) -> Next: (37.5107283, 22.38564) | Bearing: 233.76° | Orientation: Southwest
# Current: (37.5107283, 22.38564) -> Next: (37.5106249, 22.385425) | Bearing: 238.77° | Orientation: Southwest
# Current: (37.5106249, 22.385425) -> Next: (37.5105716, 22.3851933) | Bearing: 253.83° | Orientation: West
# Current: (37.5105716, 22.3851933) -> Next: (37.5104616, 22.38498) | Bearing: 236.97° | Orientation: Southwest
# Current: (37.5104616, 22.38498) -> Next: (37.5104083, 22.38476) | Bearing: 253.02° | Orientation: West
# Current: (37.5104083, 22.38476) -> Next: (37.5103766, 22.3846983) | Bearing: 237.07° | Orientation: Southwest
# Current: (37.5103766, 22.3846983) -> Next: (37.51096, 22.3865933) | Bearing: 68.79° | Orientation: East
# Current: (37.51096, 22.3865933) -> Next: (37.5109433, 22.3864633) | Bearing: 260.80° | Orientation: West
# Current: (37.5109433, 22.3864633) -> Next: (37.5109033, 22.386425) | Bearing: 217.22° | Orientation: Southwest
# Current: (37.5109033, 22.386425) -> Next: (37.5109316, 22.3862533) | Bearing: 281.74° | Orientation: West
# Current: (37.5109316, 22.3862533) -> Next: (37.5111366, 22.3861666) | Bearing: 341.45° | Orientation: North
# Current: (37.5111366, 22.3861666) -> Next: (37.5112666, 22.3861349) | Bearing: 349.05° | Orientation: North
# Current: (37.5112666, 22.3861349) -> Next: (37.5104416, 22.3870566) | Bearing: 138.45° | Orientation: Southeast
# Current: (37.5104416, 22.3870566) -> Next: (37.5105316, 22.3866833) | Bearing: 286.91° | Orientation: West
# Current: (37.5105316, 22.3866833) -> Next: (37.5106016, 22.3864266) | Bearing: 288.97° | Orientation: West
# Current: (37.5106016, 22.3864266) -> Next: (37.5106983, 22.3861) | Bearing: 290.47° | Orientation: West
# Current: (37.5106983, 22.3861) -> Next: (37.51081, 22.3857216) | Bearing: 290.41° | Orientation: West
# Current: (37.51081, 22.3857216) -> Next: (37.5108866, 22.3852566) | Bearing: 281.73° | Orientation: West
# Current: (37.5108866, 22.3852566) -> Next: (37.51068, 22.3865033) | Bearing: 101.80° | Orientation: East
# Current: (37.51068, 22.3865033) -> Next: (37.5107033, 22.386265) | Bearing: 277.03° | Orientation: West
# Current: (37.5107033, 22.386265) -> Next: (37.510875, 22.385405) | Bearing: 284.13° | Orientation: West
# Current: (37.510875, 22.385405) -> Next: (37.5108983, 22.3854283) | Bearing: 38.42° | Orientation: Northeast
# Current: (37.5108983, 22.3854283) -> Next: (37.5109183, 22.3854766) | Bearing: 62.43° | Orientation: Northeast
# Current: (37.5109183, 22.3854766) -> Next: (37.5109266, 22.3855433) | Bearing: 81.08° | Orientation: East
# Current: (37.5109266, 22.3855433) -> Next: (37.5109683, 22.3854583) | Bearing: 301.74° | Orientation: Northwest
# Current: (37.5109683, 22.3854583) -> Next: (37.5109183, 22.3851633) | Bearing: 257.94° | Orientation: West
# Current: (37.5109183, 22.3851633) -> Next: (37.5109516, 22.3848933) | Bearing: 278.84° | Orientation: West
# Current: (37.5109516, 22.3848933) -> Next: (37.5110516, 22.3846583) | Bearing: 298.21° | Orientation: Northwest
# Current: (37.5110516, 22.3846583) -> Next: (37.5110783, 22.3872233) | Bearing: 89.25° | Orientation: East
# Current: (37.5110783, 22.3872233) -> Next: (37.51109, 22.3874633) | Bearing: 86.48° | Orientation: East
# Current: (37.51109, 22.3874633) -> Next: (37.5109866, 22.3877583) | Bearing: 113.84° | Orientation: Southeast
# Current: (37.5109866, 22.3877583) -> Next: (37.5107733, 22.3877166) | Bearing: 188.82° | Orientation: South
# Current: (37.5107733, 22.3877166) -> Next: (37.5106983, 22.3875) | Bearing: 246.42° | Orientation: Southwest
# Current: (37.5106983, 22.3875) -> Next: (37.5106999, 22.3874233) | Bearing: 271.51° | Orientation: West
# Current: (37.5106999, 22.3874233) -> Next: (37.510705, 22.38731) | Bearing: 273.25° | Orientation: West
# Current: (37.510705, 22.38731) -> Next: (37.5108616, 22.3862216) | Bearing: 280.28° | Orientation: West
# Current: (37.5108616, 22.3862216) -> Next: (37.510955, 22.3860949) | Bearing: 312.90° | Orientation: Northwest
# Current: (37.510955, 22.3860949) -> Next: (37.5109866, 22.3861816) | Bearing: 65.32° | Orientation: Northeast
# Current: (37.5109866, 22.3861816) -> Next: (37.5110166, 22.3861566) | Bearing: 326.53° | Orientation: Northwest
# Current: (37.5110166, 22.3861566) -> Next: (37.51098, 22.3862133) | Bearing: 129.14° | Orientation: Southeast
# Current: (37.51098, 22.3862133) -> Next: (37.5109566, 22.3862333) | Bearing: 145.86° | Orientation: Southeast
# Current: (37.5109566, 22.3862333) -> Next: (37.5108766, 22.3862183) | Bearing: 188.46° | Orientation: South
# Current: (37.5108766, 22.3862183) -> Next: (37.5108583, 22.3862733) | Bearing: 112.76° | Orientation: Southeast
# Current: (37.5108583, 22.3862733) -> Next: (37.5108033, 22.38614) | Bearing: 242.52° | Orientation: Southwest
# Current: (37.5108033, 22.38614) -> Next: (37.5108433, 22.3862033) | Bearing: 51.46° | Orientation: Northeast
# Current: (37.5108433, 22.3862033) -> Next: (37.5106983, 22.38634) | Bearing: 143.21° | Orientation: Southeast
# Current: (37.5106983, 22.38634) -> Next: (37.5106999, 22.38635) | Bearing: 78.60° | Orientation: East
# Current: (37.5106999, 22.38635) -> Next: (37.510855, 22.3860499) | Bearing: 303.09° | Orientation: Northwest
# Current: (37.510855, 22.3860499) -> Next: (37.5108516, 22.3857899) | Bearing: 269.06° | Orientation: West
# Current: (37.5108516, 22.3857899) -> Next: (37.51083, 22.3857949) | Bearing: 169.60° | Orientation: South
# Current: (37.51083, 22.3857949) -> Next: (37.51049, 22.3869833) | Bearing: 109.83° | Orientation: East
# Current: (37.51049, 22.3869833) -> Next: (37.5107666, 22.3868566) | Bearing: 340.03° | Orientation: North
# Current: (37.5107666, 22.3868566) -> Next: (37.5107633, 22.3866133) | Bearing: 269.02° | Orientation: West
# Current: (37.5107633, 22.3866133) -> Next: (37.510795, 22.3865033) | Bearing: 289.97° | Orientation: West
# Current: (37.510795, 22.3865033) -> Next: (37.5107916, 22.3864766) | Bearing: 260.88° | Orientation: West
# Current: (37.5107916, 22.3864766) -> Next: (37.5107683, 22.3861783) | Bearing: 264.38° | Orientation: West
# Current: (37.5107683, 22.3861783) -> Next: (37.5107883, 22.3859383) | Bearing: 276.00° | Orientation: West
# Current: (37.5107883, 22.3859383) -> Next: (37.5107766, 22.3857916) | Bearing: 264.26° | Orientation: West
# Current: (37.5107766, 22.3857916) -> Next: (37.5107116, 22.3860499) | Bearing: 107.60° | Orientation: East
# Current: (37.5107116, 22.3860499) -> Next: (37.5107166, 22.3860299) | Bearing: 287.49° | Orientation: West
# Current: (37.5107166, 22.3860299) -> Next: (37.5107066, 22.3859933) | Bearing: 250.99° | Orientation: West
# Current: (37.5107066, 22.3859933) -> Next: (37.5107333, 22.38595) | Bearing: 307.86° | Orientation: Northwest
# Current: (37.5107333, 22.38595) -> Next: (37.5107649, 22.3856983) | Bearing: 278.99° | Orientation: West
# Current: (37.5107649, 22.3856983) -> Next: (37.5107633, 22.385625) | Bearing: 268.42° | Orientation: West
# Current: (37.5107633, 22.385625) -> Next: (37.5108216, 22.3859516) | Bearing: 77.32° | Orientation: East
# Current: (37.5108216, 22.3859516) -> Next: (37.5108616, 22.3856966) | Bearing: 281.19° | Orientation: West
# Current: (37.5108616, 22.3856966) -> Next: (37.5107966, 22.3854933) | Bearing: 248.05° | Orientation: West
# Current: (37.5107966, 22.3854933) -> Next: (37.510805, 22.3854533) | Bearing: 284.83° | Orientation: West
# Current: (37.510805, 22.3854533) -> Next: (37.51081, 22.38544) | Bearing: 295.36° | Orientation: Northwest
# Current: (37.51081, 22.38544) -> Next: (37.51101, 22.3860283) | Bearing: 66.80° | Orientation: Northeast
# Current: (37.51101, 22.3860283) -> Next: (37.5109333, 22.3860283) | Bearing: 180.00° | Orientation: South
# Current: (37.5109333, 22.3860283) -> Next: (37.5107883, 22.3861583) | Bearing: 144.58° | Orientation: Southeast
# Current: (37.5107883, 22.3861583) -> Next: (37.5107616, 22.3861283) | Bearing: 221.71° | Orientation: Southwest
# Current: (37.5107616, 22.3861283) -> Next: (37.5108266, 22.385865) | Bearing: 287.29° | Orientation: West
# Current: (37.5108266, 22.385865) -> Next: (37.5110449, 22.3855049) | Bearing: 307.39° | Orientation: Northwest
# Current: (37.5110449, 22.3855049) -> Next: (37.5110633, 22.3862016) | Bearing: 88.09° | Orientation: East
# Current: (37.5110633, 22.3862016) -> Next: (37.5110333, 22.3861666) | Bearing: 222.78° | Orientation: Southwest
# Current: (37.5110333, 22.3861666) -> Next: (37.5110333, 22.3862316) | Bearing: 90.00° | Orientation: East
# Current: (37.5110333, 22.3862316) -> Next: (37.5110833, 22.3861333) | Bearing: 302.67° | Orientation: Northwest
# Current: (37.5110833, 22.3861333) -> Next: (37.5110449, 22.38615) | Bearing: 160.97° | Orientation: South
# Current: (37.5110449, 22.38615) -> Next: (37.5108933, 22.3859783) | Bearing: 221.94° | Orientation: Southwest
# Current: (37.5108933, 22.3859783) -> Next: (37.5108616, 22.385995) | Bearing: 157.32° | Orientation: Southeast
# Current: (37.5108616, 22.385995) -> Next: (37.5109133, 22.3860183) | Bearing: 19.67° | Orientation: North
# Current: (37.5109133, 22.3860183) -> Next: (37.5109633, 22.38599) | Bearing: 335.82° | Orientation: Northwest
# Current: (37.5109633, 22.38599) -> Next: (37.5105766, 22.387055) | Bearing: 114.60° | Orientation: Southeast
# Current: (37.5105766, 22.387055) -> Next: (37.5112283, 22.3862) | Bearing: 313.86° | Orientation: Northwest
# Current: (37.5112283, 22.3862) -> Next: (37.51138, 22.3862383) | Bearing: 11.32° | Orientation: North
# Current: (37.51138, 22.3862383) -> Next: (37.5108233, 22.3865016) | Bearing: 159.44° | Orientation: South
# Current: (37.5108233, 22.3865016) -> Next: (37.5108, 22.386435) | Bearing: 246.20° | Orientation: Southwest
# Current: (37.5108, 22.386435) -> Next: (37.5108066, 22.3865033) | Bearing: 83.05° | Orientation: East
# Current: (37.5108066, 22.3865033) -> Next: (37.5107716, 22.3865083) | Bearing: 173.53° | Orientation: South
# Current: (37.5107716, 22.3865083) -> Next: (37.5107866, 22.3864383) | Bearing: 285.12° | Orientation: West
# Current: (37.5107866, 22.3864383) -> Next: (37.5108633, 22.3863916) | Bearing: 334.22° | Orientation: Northwest
# Current: (37.5108633, 22.3863916) -> Next: (37.5107266, 22.386365) | Bearing: 188.77° | Orientation: South
# Current: (37.5107266, 22.386365) -> Next: (37.5107649, 22.3864183) | Bearing: 47.83° | Orientation: Northeast
# Current: (37.5107649, 22.3864183) -> Next: (37.5107666, 22.3863516) | Bearing: 271.84° | Orientation: West
# Current: (37.5107666, 22.3863516) -> Next: (37.5106283, 22.3862216) | Bearing: 216.71° | Orientation: Southwest
# Current: (37.5106283, 22.3862216) -> Next: (37.5107116, 22.386005) | Bearing: 295.87° | Orientation: Northwest
# Current: (37.5107116, 22.386005) -> Next: (37.5107749, 22.3857733) | Bearing: 289.00° | Orientation: West
# Current: (37.5107749, 22.3857733) -> Next: (37.5107783, 22.3857216) | Bearing: 274.74° | Orientation: West
# Current: (37.5107783, 22.3857216) -> Next: (37.5119066, 22.3840066) | Bearing: 309.67° | Orientation: Northwest
# Current: (37.5119066, 22.3840066) -> Next: (37.5120999, 22.3840999) | Bearing: 20.95° | Orientation: North
# Current: (37.5120999, 22.3840999) -> Next: (37.5121149, 22.3841183) | Bearing: 44.22° | Orientation: Northeast
# Current: (37.5121149, 22.3841183) -> Next: (37.5107266, 22.386175) | Bearing: 130.40° | Orientation: Southeast
# Current: (37.5107266, 22.386175) -> Next: (37.51079, 22.3861916) | Bearing: 11.73° | Orientation: North
# Current: (37.51079, 22.3861916) -> Next: (37.5108316, 22.3861799) | Bearing: 347.42° | Orientation: North
# Current: (37.5108316, 22.3861799) -> Next: (37.5109999, 22.3861116) | Bearing: 342.16° | Orientation: North
# Current: (37.5109999, 22.3861116) -> Next: (37.511005, 22.3861733) | Bearing: 84.05° | Orientation: East
# Current: (37.511005, 22.3861733) -> Next: (37.51102, 22.3862216) | Bearing: 68.62° | Orientation: East
# Current: (37.51102, 22.3862216) -> Next: (37.51073, 22.3869983) | Bearing: 115.21° | Orientation: Southeast
# Current: (37.51073, 22.3869983) -> Next: (37.5108166, 22.3868266) | Bearing: 302.45° | Orientation: Northwest
# Current: (37.5108166, 22.3868266) -> Next: (37.5108066, 22.3869183) | Bearing: 97.83° | Orientation: East
# Current: (37.5108066, 22.3869183) -> Next: (37.510755, 22.3869733) | Bearing: 139.79° | Orientation: Southeast
# Current: (37.510755, 22.3869733) -> Next: (37.5109166, 22.3856633) | Bearing: 278.84° | Orientation: West
# Current: (37.5109166, 22.3856633) -> Next: (37.5109816, 22.3854883) | Bearing: 295.09° | Orientation: Northwest
# Current: (37.5109816, 22.3854883) -> Next: (37.5109416, 22.3863916) | Bearing: 93.19° | Orientation: East
# Current: (37.5109416, 22.3863916) -> Next: (37.5109516, 22.3865566) | Bearing: 85.63° | Orientation: East
# Current: (37.5109516, 22.3865566) -> Next: (37.5109716, 22.3864416) | Bearing: 282.37° | Orientation: West
# Current: (37.5109716, 22.3864416) -> Next: (37.5108683, 22.3862433) | Bearing: 236.71° | Orientation: Southwest
# Current: (37.5108683, 22.3862433) -> Next: (37.5108199, 22.3860299) | Bearing: 254.04° | Orientation: West
# Current: (37.5108199, 22.3860299) -> Next: (37.5109033, 22.3863916) | Bearing: 73.79° | Orientation: East
# Current: (37.5109033, 22.3863916) -> Next: (37.51096, 22.3861816) | Bearing: 288.80° | Orientation: West
# Current: (37.51096, 22.3861816) -> Next: (37.5109666, 22.386175) | Bearing: 321.58° | Orientation: Northwest
# Current: (37.5109666, 22.386175) -> Next: (37.5109633, 22.3861583) | Bearing: 256.01° | Orientation: West
# Current: (37.5109633, 22.3861583) -> Next: (37.5109816, 22.38607) | Bearing: 284.64° | Orientation: West
# Current: (37.5109816, 22.38607) -> Next: (37.511055, 22.3858583) | Bearing: 293.61° | Orientation: Northwest
# Current: (37.511055, 22.3858583) -> Next: (37.5110683, 22.3856783) | Bearing: 275.32° | Orientation: West
# Current: (37.5110683, 22.3856783) -> Next: (37.5110083, 22.3861316) | Bearing: 99.47° | Orientation: East
# Current: (37.5110083, 22.3861316) -> Next: (37.5108833, 22.3863466) | Bearing: 126.24° | Orientation: Southeast
# Current: (37.5108833, 22.3863466) -> Next: (37.5107683, 22.3865666) | Bearing: 123.38° | Orientation: Southeast
# Current: (37.5107683, 22.3865666) -> Next: (37.5106616, 22.3866816) | Bearing: 139.47° | Orientation: Southeast
# Current: (37.5106616, 22.3866816) -> Next: (37.5106766, 22.3865533) | Bearing: 278.38° | Orientation: West
# Current: (37.5106766, 22.3865533) -> Next: (37.5106999, 22.3865433) | Bearing: 341.20° | Orientation: North
# Current: (37.5106999, 22.3865433) -> Next: (37.5107116, 22.3865616) | Bearing: 51.13° | Orientation: Northeast
# Current: (37.5107116, 22.3865616) -> Next: (37.5107616, 22.3860966) | Bearing: 277.72° | Orientation: West
# Current: (37.5107616, 22.3860966) -> Next: (37.510885, 22.38592) | Bearing: 311.38° | Orientation: Northwest
# Current: (37.510885, 22.38592) -> Next: (37.511005, 22.3858433) | Bearing: 333.11° | Orientation: Northwest
# Current: (37.511005, 22.3858433) -> Next: (37.5110483, 22.3858966) | Bearing: 44.32° | Orientation: Northeast
# Current: (37.5110483, 22.3858966) -> Next: (37.5106883, 22.3866616) | Bearing: 120.68° | Orientation: Southeast
# Current: (37.5106883, 22.3866616) -> Next: (37.510725, 22.38645) | Bearing: 282.33° | Orientation: West
# Current: (37.510725, 22.38645) -> Next: (37.5107483, 22.3862883) | Bearing: 280.30° | Orientation: West
# Current: (37.5107483, 22.3862883) -> Next: (37.51078, 22.38658) | Bearing: 82.20° | Orientation: East
# Current: (37.51078, 22.38658) -> Next: (37.5107866, 22.3864833) | Bearing: 274.92° | Orientation: West
# Current: (37.5107866, 22.3864833) -> Next: (37.51087, 22.38661) | Bearing: 50.31° | Orientation: Northeast
# Current: (37.51087, 22.38661) -> Next: (37.5108916, 22.3865433) | Bearing: 292.21° | Orientation: West
# Current: (37.5108916, 22.3865433) -> Next: (37.51096, 22.3862833) | Bearing: 288.35° | Orientation: West
# Current: (37.51096, 22.3862833) -> Next: (37.5110066, 22.3860816) | Bearing: 286.24° | Orientation: West
# Current: (37.5110066, 22.3860816) -> Next: (37.5105916, 22.3819616) | Bearing: 262.76° | Orientation: West
# Current: (37.5105916, 22.3819616) -> Next: (37.5106433, 22.381715) | Bearing: 284.80° | Orientation: West
# Current: (37.5106433, 22.381715) -> Next: (37.5106733, 22.3814116) | Bearing: 277.11° | Orientation: West
# Current: (37.5106733, 22.3814116) -> Next: (37.5105999, 22.3811433) | Bearing: 250.97° | Orientation: West
# Current: (37.5105999, 22.3811433) -> Next: (37.5105416, 22.3809083) | Bearing: 252.63° | Orientation: West
# Current: (37.5105416, 22.3809083) -> Next: (37.5105249, 22.3808216) | Bearing: 256.35° | Orientation: West
# Current: (37.5105249, 22.3808216) -> Next: (37.51102, 22.3854966) | Bearing: 82.39° | Orientation: East
# Current: (37.51102, 22.3854966) -> Next: (37.51105, 22.3853099) | Bearing: 281.45° | Orientation: West
# Current: (37.51105, 22.3853099) -> Next: (37.5116966, 22.3788333) | Bearing: 277.18° | Orientation: West
# Current: (37.5116966, 22.3788333) -> Next: (37.5116866, 22.3785616) | Bearing: 267.34° | Orientation: West
# Current: (37.5116866, 22.3785616) -> Next: (37.5116716, 22.37832) | Bearing: 265.52° | Orientation: West
# Current: (37.5116716, 22.37832) -> Next: (37.5115999, 22.3780816) | Bearing: 249.24° | Orientation: West
# Current: (37.5115999, 22.3780816) -> Next: (37.5114983, 22.377855) | Bearing: 240.52° | Orientation: Southwest
# Current: (37.5114983, 22.377855) -> Next: (37.5115433, 22.3776666) | Bearing: 286.76° | Orientation: West
# Current: (37.5115433, 22.3776666) -> Next: (37.511565, 22.3775733) | Bearing: 286.34° | Orientation: West
# Current: (37.511565, 22.3775733) -> Next: (37.5067816, 22.3741016) | Bearing: 209.93° | Orientation: Southwest
# Current: (37.5067816, 22.3741016) -> Next: (37.5068383, 22.3738033) | Bearing: 283.47° | Orientation: West
# Current: (37.5068383, 22.3738033) -> Next: (37.5068833, 22.3735533) | Bearing: 282.78° | Orientation: West
# Current: (37.5068833, 22.3735533) -> Next: (37.5069283, 22.373295) | Bearing: 282.39° | Orientation: West
# Current: (37.5069283, 22.373295) -> Next: (37.5069366, 22.3730466) | Bearing: 272.41° | Orientation: West
# Current: (37.5069366, 22.3730466) -> Next: (37.50693, 22.3728066) | Bearing: 268.01° | Orientation: West
# Current: (37.50693, 22.3728066) -> Next: (37.508445, 22.3707833) | Bearing: 313.35° | Orientation: Northwest
# Current: (37.508445, 22.3707833) -> Next: (37.5085433, 22.370655) | Bearing: 314.00° | Orientation: Northwest
# Current: (37.5085433, 22.370655) -> Next: (37.5082716, 22.360795) | Bearing: 268.01° | Orientation: West
# Current: (37.5082716, 22.360795) -> Next: (37.5082483, 22.3610383) | Bearing: 96.88° | Orientation: East
# Current: (37.5082483, 22.3610383) -> Next: (37.5081633, 22.3611783) | Bearing: 127.43° | Orientation: Southeast
# Current: (37.5081633, 22.3611783) -> Next: (37.508165, 22.361175) | Bearing: 303.00° | Orientation: Northwest
# Current: (37.508165, 22.361175) -> Next: (37.511235, 22.3841449) | Bearing: 80.43° | Orientation: East
# Current: (37.511235, 22.3841449) -> Next: (37.5112433, 22.3840516) | Bearing: 276.40° | Orientation: West
# Current: (37.5112433, 22.3840516) -> Next: (37.5112216, 22.3839199) | Bearing: 258.27° | Orientation: West
# Current: (37.5112216, 22.3839199) -> Next: (37.5113433, 22.3837416) | Bearing: 310.71° | Orientation: Northwest
# Current: (37.5113433, 22.3837416) -> Next: (37.51141, 22.3835033) | Bearing: 289.44° | Orientation: West
# Current: (37.51141, 22.3835033) -> Next: (37.5114216, 22.3832366) | Bearing: 273.14° | Orientation: West
# Current: (37.5114216, 22.3832366) -> Next: (37.5108266, 22.3861333) | Bearing: 104.52° | Orientation: East
# Current: (37.5108266, 22.3861333) -> Next: (37.51092, 22.3860299) | Bearing: 318.71° | Orientation: Northwest
# Current: (37.51092, 22.3860299) -> Next: (37.5110016, 22.3861316) | Bearing: 44.67° | Orientation: Northeast
# Current: (37.5110016, 22.3861316) -> Next: (37.5109933, 22.3860866) | Bearing: 256.91° | Orientation: West
# Current: (37.5109933, 22.3860866) -> Next: (37.51101, 22.3860833) | Bearing: 351.09° | Orientation: North
# Current: (37.51101, 22.3860833) -> Next: (37.5107633, 22.3861766) | Bearing: 163.30° | Orientation: South
# Current: (37.5107633, 22.3861766) -> Next: (37.5107649, 22.3860016) | Bearing: 270.66° | Orientation: West
# Current: (37.5107649, 22.3860016) -> Next: (37.510755, 22.3861) | Bearing: 97.23° | Orientation: East
# Current: (37.510755, 22.3861) -> Next: (37.5107866, 22.3860083) | Bearing: 293.48° | Orientation: Northwest
# Current: (37.5107866, 22.3860083) -> Next: (37.5107866, 22.3859983) | Bearing: 270.00° | Orientation: West
# Current: (37.5107866, 22.3859983) -> Next: (37.51078, 22.3860116) | Bearing: 122.03° | Orientation: Southeast
# Current: (37.51078, 22.3860116) -> Next: (37.5107866, 22.385775) | Bearing: 272.01° | Orientation: West
# Current: (37.5107866, 22.385775) -> Next: (37.5108066, 22.3856583) | Bearing: 282.19° | Orientation: West
# Current: (37.5108066, 22.3856583) -> Next: (37.5108183, 22.3863433) | Bearing: 88.77° | Orientation: East
# Current: (37.5108183, 22.3863433) -> Next: (37.5107483, 22.3864566) | Bearing: 127.91° | Orientation: Southeast
# Current: (37.5107483, 22.3864566) -> Next: (37.5107583, 22.38625) | Bearing: 273.49° | Orientation: West
# Current: (37.5107583, 22.38625) -> Next: (37.510795, 22.3859683) | Bearing: 279.33° | Orientation: West
# Current: (37.510795, 22.3859683) -> Next: (37.5108483, 22.3858716) | Bearing: 304.79° | Orientation: Northwest
# Current: (37.5108483, 22.3858716) -> Next: (37.5109783, 22.3857783) | Bearing: 330.35° | Orientation: Northwest
# Current: (37.5109783, 22.3857783) -> Next: (37.5110733, 22.3858566) | Bearing: 33.18° | Orientation: Northeast
# Current: (37.5110733, 22.3858566) -> Next: (37.5107666, 22.3861416) | Bearing: 143.61° | Orientation: Southeast
# Current: (37.5107666, 22.3861416) -> Next: (37.5107516, 22.3858983) | Bearing: 265.56° | Orientation: West
# Current: (37.5107516, 22.3858983) -> Next: (37.5107483, 22.3857966) | Bearing: 267.66° | Orientation: West
# Current: (37.5107483, 22.3857966) -> Next: (37.5106999, 22.38556) | Bearing: 255.54° | Orientation: West
# Current: (37.5106999, 22.38556) -> Next: (37.510715, 22.385305) | Bearing: 274.27° | Orientation: West
# Current: (37.510715, 22.385305) -> Next: (37.5107183, 22.385035) | Bearing: 270.88° | Orientation: West
# Current: (37.5107183, 22.385035) -> Next: (37.5110316, 22.3860149) | Bearing: 68.05° | Orientation: East
# Current: (37.5110316, 22.3860149) -> Next: (37.51098, 22.3862566) | Bearing: 105.06° | Orientation: East
# Current: (37.51098, 22.3862566) -> Next: (37.5110133, 22.3860366) | Bearing: 280.80° | Orientation: West
# Current: (37.5110133, 22.3860366) -> Next: (37.5110666, 22.385815) | Bearing: 286.87° | Orientation: West
# Current: (37.5110666, 22.385815) -> Next: (37.5110883, 22.3857499) | Bearing: 292.79° | Orientation: Northwest
# Current: (37.5110883, 22.3857499) -> Next: (37.5111566, 22.3857) | Bearing: 329.91° | Orientation: Northwest
# Current: (37.5111566, 22.3857) -> Next: (37.511185, 22.3862216) | Bearing: 86.07° | Orientation: East
# Current: (37.511185, 22.3862216) -> Next: (37.5112683, 22.386075) | Bearing: 305.61° | Orientation: Northwest
# Current: (37.5112683, 22.386075) -> Next: (37.5111666, 22.3858816) | Bearing: 236.46° | Orientation: Southwest
# Current: (37.5111666, 22.3858816) -> Next: (37.5111866, 22.3856333) | Bearing: 275.80° | Orientation: West
# Current: (37.5111866, 22.3856333) -> Next: (37.5112283, 22.38562) | Bearing: 345.80° | Orientation: North
# Current: (37.5112283, 22.38562) -> Next: (37.511155, 22.3861483) | Bearing: 99.92° | Orientation: East
# Current: (37.511155, 22.3861483) -> Next: (37.511095, 22.3860816) | Bearing: 221.41° | Orientation: Southwest
# Current: (37.511095, 22.3860816) -> Next: (37.5110833, 22.3861433) | Bearing: 103.44° | Orientation: East
# Current: (37.5110833, 22.3861433) -> Next: (37.5111566, 22.3861533) | Bearing: 6.18° | Orientation: North
# Current: (37.5111566, 22.3861533) -> Next: (37.5111583, 22.386145) | Bearing: 284.48° | Orientation: West
# Current: (37.5111583, 22.386145) -> Next: (37.5113316, 22.3860266) | Bearing: 331.54° | Orientation: Northwest
# Current: (37.5113316, 22.3860266) -> Next: (37.5113016, 22.3859833) | Bearing: 228.86° | Orientation: Southwest
# Current: (37.5113016, 22.3859833) -> Next: (37.510725, 22.3859733) | Bearing: 180.79° | Orientation: South
# Current: (37.510725, 22.3859733) -> Next: (37.5106849, 22.3857199) | Bearing: 258.72° | Orientation: West
# Current: (37.5106849, 22.3857199) -> Next: (37.510755, 22.3854949) | Bearing: 291.44° | Orientation: West
# Current: (37.510755, 22.3854949) -> Next: (37.5107383, 22.3858433) | Bearing: 93.46° | Orientation: East
# Current: (37.5107383, 22.3858433) -> Next: (37.5107383, 22.3856066) | Bearing: 270.00° | Orientation: West
# Current: (37.5107383, 22.3856066) -> Next: (37.5107333, 22.38533) | Bearing: 268.69° | Orientation: West
# Current: (37.5107333, 22.38533) -> Next: (37.5106849, 22.3850683) | Bearing: 256.88° | Orientation: West
# Current: (37.5106849, 22.3850683) -> Next: (37.5107016, 22.384825) | Bearing: 274.95° | Orientation: West
# Current: (37.5107016, 22.384825) -> Next: (37.510715, 22.3847316) | Bearing: 280.25° | Orientation: West
# Current: (37.510715, 22.3847316) -> Next: (37.51063, 22.3857366) | Bearing: 96.09° | Orientation: East
# Current: (37.51063, 22.3857366) -> Next: (37.5106366, 22.3858333) | Bearing: 85.08° | Orientation: East
# Current: (37.5106366, 22.3858333) -> Next: (37.5106583, 22.3858483) | Bearing: 28.74° | Orientation: Northeast
# Current: (37.5106583, 22.3858483) -> Next: (37.5105766, 22.3856783) | Bearing: 238.79° | Orientation: Southwest
# Current: (37.5105766, 22.3856783) -> Next: (37.5107466, 22.384825) | Bearing: 284.10° | Orientation: West
# Current: (37.5107466, 22.384825) -> Next: (37.5107466, 22.384585) | Bearing: 270.00° | Orientation: West
# Current: (37.5107466, 22.384585) -> Next: (37.5106716, 22.3856483) | Bearing: 95.08° | Orientation: East
# Current: (37.5106716, 22.3856483) -> Next: (37.5107566, 22.3857183) | Bearing: 33.15° | Orientation: Northeast
# Current: (37.5107566, 22.3857183) -> Next: (37.510875, 22.3859433) | Bearing: 56.44° | Orientation: Northeast
# Current: (37.510875, 22.3859433) -> Next: (37.5109166, 22.386045) | Bearing: 62.72° | Orientation: Northeast
# Current: (37.5109166, 22.386045) -> Next: (37.5106716, 22.3862483) | Bearing: 146.65° | Orientation: Southeast
# Current: (37.5106716, 22.3862483) -> Next: (37.51064, 22.3861733) | Bearing: 242.02° | Orientation: Southwest
# Current: (37.51064, 22.3861733) -> Next: (37.5106066, 22.3862233) | Bearing: 130.10° | Orientation: Southeast
# Current: (37.5106066, 22.3862233) -> Next: (37.5105383, 22.3862366) | Bearing: 171.22° | Orientation: South
# Current: (37.5105383, 22.3862366) -> Next: (37.5105433, 22.38622) | Bearing: 290.79° | Orientation: West
# Current: (37.5105433, 22.38622) -> Next: (37.5105949, 22.3861916) | Bearing: 336.41° | Orientation: Northwest
# Current: (37.5105949, 22.3861916) -> Next: (37.510605, 22.3861683) | Bearing: 298.65° | Orientation: Northwest
# Current: (37.510605, 22.3861683) -> Next: (37.5106216, 22.3861349) | Bearing: 302.07° | Orientation: Northwest
# Current: (37.5106216, 22.3861349) -> Next: (37.5106216, 22.3861349) | Bearing: 0.00° | Orientation: North
# Current: (37.5106216, 22.3861349) -> Next: (37.5106516, 22.386635) | Bearing: 85.68° | Orientation: East
# Current: (37.5106516, 22.386635) -> Next: (37.5107166, 22.3866216) | Bearing: 350.71° | Orientation: North
# Current: (37.5107166, 22.3866216) -> Next: (37.5108833, 22.3865316) | Bearing: 336.82° | Orientation: Northwest
# Current: (37.5108833, 22.3865316) -> Next: (37.5109133, 22.3864716) | Bearing: 302.22° | Orientation: Northwest
# Current: (37.5109133, 22.3864716) -> Next: (37.5108683, 22.3863766) | Bearing: 239.16° | Orientation: Southwest
# Current: (37.5108683, 22.3863766) -> Next: (37.5108833, 22.386265) | Bearing: 279.62° | Orientation: West
# Current: (37.5108833, 22.386265) -> Next: (37.51102, 22.386515) | Bearing: 55.42° | Orientation: Northeast
# Current: (37.51102, 22.386515) -> Next: (37.5110483, 22.38649) | Bearing: 324.98° | Orientation: Northwest
# Current: (37.5110483, 22.38649) -> Next: (37.510785, 22.3865783) | Bearing: 165.10° | Orientation: South
# Current: (37.510785, 22.3865783) -> Next: (37.5108083, 22.3865566) | Bearing: 323.54° | Orientation: Northwest
# Current: (37.5108083, 22.3865566) -> Next: (37.51081, 22.3867033) | Bearing: 89.16° | Orientation: East
# Current: (37.51081, 22.3867033) -> Next: (37.5103966, 22.3869483) | Bearing: 154.82° | Orientation: Southeast
# Current: (37.5103966, 22.3869483) -> Next: (37.5107716, 22.38604) | Bearing: 297.50° | Orientation: Northwest
# Current: (37.5107716, 22.38604) -> Next: (37.5108166, 22.3857783) | Bearing: 282.23° | Orientation: West
# Current: (37.5108166, 22.3857783) -> Next: (37.510845, 22.385745) | Bearing: 317.07° | Orientation: Northwest
# Current: (37.510845, 22.385745) -> Next: (37.51102, 22.3853516) | Bearing: 299.28° | Orientation: Northwest
# Current: (37.51102, 22.3853516) -> Next: (37.5110316, 22.3851166) | Bearing: 273.56° | Orientation: West
# Current: (37.5110316, 22.3851166) -> Next: (37.5109583, 22.3853366) | Bearing: 112.78° | Orientation: Southeast
# Current: (37.5109583, 22.3853366) -> Next: (37.5107466, 22.38595) | Bearing: 113.51° | Orientation: Southeast
# Current: (37.5107466, 22.38595) -> Next: (37.5107366, 22.3857066) | Bearing: 267.04° | Orientation: West
# Current: (37.5107366, 22.3857066) -> Next: (37.5107616, 22.38562) | Bearing: 290.00° | Orientation: West
# Current: (37.5107616, 22.38562) -> Next: (37.51086, 22.3854166) | Bearing: 301.38° | Orientation: Northwest
# Current: (37.51086, 22.3854166) -> Next: (37.510865, 22.3853566) | Bearing: 276.00° | Orientation: West
# Current: (37.510865, 22.3853566) -> Next: (37.51074, 22.3861483) | Bearing: 101.26° | Orientation: East
# Current: (37.51074, 22.3861483) -> Next: (37.51077, 22.3861583) | Bearing: 14.81° | Orientation: North
# Current: (37.51077, 22.3861583) -> Next: (37.5108816, 22.3859916) | Bearing: 310.16° | Orientation: Northwest
# Current: (37.5108816, 22.3859916) -> Next: (37.5109816, 22.3861666) | Bearing: 54.23° | Orientation: Northeast
# Current: (37.5109816, 22.3861666) -> Next: (37.5109716, 22.385915) | Bearing: 267.13° | Orientation: West
# Current: (37.5109716, 22.385915) -> Next: (37.5108783, 22.3859166) | Bearing: 179.22° | Orientation: South
# Current: (37.5108783, 22.3859166) -> Next: (37.51071, 22.3862783) | Bearing: 120.40° | Orientation: Southeast
# Current: (37.51071, 22.3862783) -> Next: (37.5107766, 22.3860433) | Bearing: 289.66° | Orientation: West
# Current: (37.5107766, 22.3860433) -> Next: (37.5108199, 22.3858183) | Bearing: 283.64° | Orientation: West
# Current: (37.5108199, 22.3858183) -> Next: (37.51078, 22.3855699) | Bearing: 258.55° | Orientation: West
# Current: (37.51078, 22.3855699) -> Next: (37.5107833, 22.3853183) | Bearing: 270.95° | Orientation: West
# Current: (37.5107833, 22.3853183) -> Next: (37.5108249, 22.3852766) | Bearing: 321.51° | Orientation: Northwest
# Current: (37.5108249, 22.3852766) -> Next: (37.5105183, 22.3869133) | Bearing: 103.29° | Orientation: East
# Current: (37.5105183, 22.3869133) -> Next: (37.5106316, 22.3867133) | Bearing: 305.53° | Orientation: Northwest
# Current: (37.5106316, 22.3867133) -> Next: (37.5107833, 22.3865666) | Bearing: 322.51° | Orientation: Northwest
# Current: (37.5107833, 22.3865666) -> Next: (37.510795, 22.3865333) | Bearing: 293.89° | Orientation: Northwest
# Current: (37.510795, 22.3865333) -> Next: (37.5109416, 22.3864716) | Bearing: 341.54° | Orientation: North
# Current: (37.5109416, 22.3864716) -> Next: (37.5110649, 22.3862866) | Bearing: 310.04° | Orientation: Northwest
# Current: (37.5110649, 22.3862866) -> Next: (37.5110616, 22.3863199) | Bearing: 97.12° | Orientation: East
# Current: (37.5110616, 22.3863199) -> Next: (37.511005, 22.3863733) | Bearing: 143.19° | Orientation: Southeast
# Current: (37.511005, 22.3863733) -> Next: (37.5109749, 22.3862366) | Bearing: 254.49° | Orientation: West
# Current: (37.5109749, 22.3862366) -> Next: (37.5108483, 22.386025) | Bearing: 232.97° | Orientation: Southwest
# Current: (37.5108483, 22.386025) -> Next: (37.5108499, 22.3860433) | Bearing: 83.71° | Orientation: East
# Current: (37.5108499, 22.3860433) -> Next: (37.5107833, 22.3861733) | Bearing: 122.86° | Orientation: Southeast
# Current: (37.5107833, 22.3861733) -> Next: (37.5107616, 22.3858966) | Bearing: 264.35° | Orientation: West
# Current: (37.5107616, 22.3858966) -> Next: (37.5107483, 22.3856216) | Bearing: 266.51° | Orientation: West
# ...
# Current: (38.047015, 23.7639716) -> Next: (38.04709, 23.76397) | Bearing: 359.04° | Orientation: North
# Current: (38.04709, 23.76397) -> Next: (38.0471633, 23.7639633) | Bearing: 355.88° | Orientation: North
# Current: (38.0471633, 23.7639633) -> Next: (38.047225, 23.7640216) | Bearing: 36.65° | Orientation: Northeast
# Current: (38.047225, 23.7640216) -> Next: (38.0472666, 23.763995) | Bearing: 333.27° | Orientation: Northwest
# Current: (38.0472666, 23.763995) -> Next: (38.0473483, 23.76404) | Bearing: 23.45° | Orientation: Northeast
# Current: (38.0473483, 23.76404) -> Next: (38.0473916, 23.7640666) | Bearing: 25.82° | Orientation: Northeast
# Current: (38.0473916, 23.7640666) -> Next: (38.0474766, 23.7641233) | Bearing: 27.71° | Orientation: Northeast
# Current: (38.0474766, 23.7641233) -> Next: (38.0475466, 23.764165) | Bearing: 25.13° | Orientation: Northeast
# Current: (38.0475466, 23.764165) -> Next: (38.0475666, 23.7641583) | Bearing: 345.22° | Orientation: North
# Current: (38.0475666, 23.7641583) -> Next: (38.047615, 23.7641666) | Bearing: 7.69° | Orientation: North
# Current: (38.047615, 23.7641666) -> Next: (38.0476699, 23.7641883) | Bearing: 17.29° | Orientation: North
# Current: (38.0476699, 23.7641883) -> Next: (38.0477033, 23.7642133) | Bearing: 30.52° | Orientation: Northeast
# Current: (38.0477033, 23.7642133) -> Next: (38.04775, 23.7642333) | Bearing: 18.64° | Orientation: North
# Current: (38.04775, 23.7642333) -> Next: (38.0477733, 23.7642616) | Bearing: 43.73° | Orientation: Northeast
# Current: (38.0477733, 23.7642616) -> Next: (38.047785, 23.76428) | Bearing: 51.08° | Orientation: Northeast
# Current: (38.047785, 23.76428) -> Next: (38.0478233, 23.764285) | Bearing: 5.87° | Orientation: North
# Current: (38.0478233, 23.764285) -> Next: (38.047875, 23.7643349) | Bearing: 37.24° | Orientation: Northeast
# Current: (38.047875, 23.7643349) -> Next: (38.0479333, 23.76436) | Bearing: 18.73° | Orientation: North
# Current: (38.0479333, 23.76436) -> Next: (38.0479533, 23.7643433) | Bearing: 326.67° | Orientation: Northwest
# Current: (38.0479533, 23.7643433) -> Next: (38.047975, 23.7643) | Bearing: 302.47° | Orientation: Northwest
# Current: (38.047975, 23.7643) -> Next: (38.0480083, 23.7642499) | Bearing: 310.17° | Orientation: Northwest
# Current: (38.0480083, 23.7642499) -> Next: (38.0479933, 23.7641716) | Bearing: 256.33° | Orientation: West
# Current: (38.0479933, 23.7641716) -> Next: (38.0479916, 23.7641099) | Bearing: 268.00° | Orientation: West
# Current: (38.0479916, 23.7641099) -> Next: (38.0480199, 23.7640333) | Bearing: 295.13° | Orientation: Northwest
# Current: (38.0480199, 23.7640333) -> Next: (38.0480316, 23.763965) | Bearing: 282.27° | Orientation: West
# Current: (38.0480316, 23.763965) -> Next: (38.0480366, 23.7639149) | Bearing: 277.22° | Orientation: West
# Current: (38.0480366, 23.7639149) -> Next: (38.0480316, 23.7638716) | Bearing: 261.66° | Orientation: West
# Current: (38.0480316, 23.7638716) -> Next: (38.0480666, 23.7637916) | Bearing: 299.05° | Orientation: Northwest
# Current: (38.0480666, 23.7637916) -> Next: (38.0480916, 23.7637716) | Bearing: 327.79° | Orientation: Northwest
# Current: (38.0480916, 23.7637716) -> Next: (38.0481433, 23.7636916) | Bearing: 309.37° | Orientation: Northwest
# Current: (38.0481433, 23.7636916) -> Next: (38.048185, 23.7636083) | Bearing: 302.44° | Orientation: Northwest
# Current: (38.048185, 23.7636083) -> Next: (38.0482283, 23.7635166) | Bearing: 300.95° | Orientation: Northwest
# Current: (38.0482283, 23.7635166) -> Next: (38.0482616, 23.7634283) | Bearing: 295.59° | Orientation: Northwest
# Current: (38.0482616, 23.7634283) -> Next: (38.0483, 23.7633383) | Bearing: 298.45° | Orientation: Northwest
# Current: (38.0483, 23.7633383) -> Next: (38.0483283, 23.76329) | Bearing: 306.65° | Orientation: Northwest
# Current: (38.0483283, 23.76329) -> Next: (38.0483633, 23.7632383) | Bearing: 310.68° | Orientation: Northwest
# Current: (38.0483633, 23.7632383) -> Next: (38.0483883, 23.7631866) | Bearing: 301.55° | Orientation: Northwest
# Current: (38.0483883, 23.7631866) -> Next: (38.0484166, 23.7631316) | Bearing: 303.16° | Orientation: Northwest
# Current: (38.0484166, 23.7631316) -> Next: (38.0483966, 23.7630616) | Bearing: 250.06° | Orientation: West
# Current: (38.0483966, 23.7630616) -> Next: (38.0484283, 23.762965) | Bearing: 292.62° | Orientation: Northwest
# Current: (38.0484283, 23.762965) -> Next: (38.0484333, 23.7628999) | Bearing: 275.57° | Orientation: West
# Current: (38.0484333, 23.7628999) -> Next: (38.0485066, 23.7628266) | Bearing: 321.78° | Orientation: Northwest
# Current: (38.0485066, 23.7628266) -> Next: (38.04855, 23.7628683) | Bearing: 37.11° | Orientation: Northeast
# Current: (38.04855, 23.7628683) -> Next: (38.0485383, 23.7628083) | Bearing: 256.09° | Orientation: West
# Current: (38.0485383, 23.7628083) -> Next: (38.0485716, 23.76276) | Bearing: 311.20° | Orientation: Northwest
# Current: (38.0485716, 23.76276) -> Next: (38.04859, 23.7626816) | Bearing: 286.60° | Orientation: West
# Current: (38.04859, 23.7626816) -> Next: (38.0486516, 23.7626333) | Bearing: 328.31° | Orientation: Northwest
# Current: (38.0486516, 23.7626333) -> Next: (38.0487233, 23.76256) | Bearing: 321.16° | Orientation: Northwest
# Current: (38.0487233, 23.76256) -> Next: (38.04879, 23.76252) | Bearing: 334.72° | Orientation: Northwest
# Current: (38.04879, 23.76252) -> Next: (38.0487883, 23.7624866) | Bearing: 266.30° | Orientation: West
# Current: (38.0487883, 23.7624866) -> Next: (38.0488116, 23.7624333) | Bearing: 299.04° | Orientation: Northwest
# Current: (38.0488116, 23.7624333) -> Next: (38.0488483, 23.7624683) | Bearing: 36.91° | Orientation: Northeast
# Current: (38.0488483, 23.7624683) -> Next: (38.0488833, 23.762505) | Bearing: 39.55° | Orientation: Northeast
# Current: (38.0488833, 23.762505) -> Next: (38.0489883, 23.7624816) | Bearing: 350.05° | Orientation: North
# Current: (38.0489883, 23.7624816) -> Next: (38.0490233, 23.7624233) | Bearing: 307.32° | Orientation: Northwest
# Current: (38.0490233, 23.7624233) -> Next: (38.049045, 23.7624083) | Bearing: 331.44° | Orientation: Northwest
# Current: (38.049045, 23.7624083) -> Next: (38.04903, 23.7623433) | Bearing: 253.67° | Orientation: West
# Current: (38.04903, 23.7623433) -> Next: (38.0490783, 23.7623466) | Bearing: 3.08° | Orientation: North
# Current: (38.0490783, 23.7623466) -> Next: (38.0491316, 23.762345) | Bearing: 358.65° | Orientation: North
# Current: (38.0491316, 23.762345) -> Next: (38.0491966, 23.7623466) | Bearing: 1.11° | Orientation: North
# Current: (38.0491966, 23.7623466) -> Next: (38.0492216, 23.7623316) | Bearing: 334.71° | Orientation: Northwest
# Current: (38.0492216, 23.7623316) -> Next: (38.04924, 23.7623133) | Bearing: 321.93° | Orientation: Northwest
# Current: (38.04924, 23.7623133) -> Next: (38.0492533, 23.7622933) | Bearing: 310.18° | Orientation: Northwest
# Current: (38.0492533, 23.7622933) -> Next: (38.0492816, 23.7622883) | Bearing: 352.08° | Orientation: North
# Current: (38.0492816, 23.7622883) -> Next: (38.0493316, 23.7622683) | Bearing: 342.52° | Orientation: North
# Current: (38.0493316, 23.7622683) -> Next: (38.0493916, 23.76227) | Bearing: 1.28° | Orientation: North
# Current: (38.0493916, 23.76227) -> Next: (38.049405, 23.7623066) | Bearing: 65.07° | Orientation: Northeast
# Current: (38.049405, 23.7623066) -> Next: (38.0493483, 23.76222) | Bearing: 230.26° | Orientation: Southwest
# Current: (38.0493483, 23.76222) -> Next: (38.049355, 23.7621383) | Bearing: 275.95° | Orientation: West
# Current: (38.049355, 23.7621383) -> Next: (38.0493833, 23.7620749) | Bearing: 299.55° | Orientation: Northwest
# Current: (38.0493833, 23.7620749) -> Next: (38.0494033, 23.7618983) | Bearing: 278.18° | Orientation: West
# Current: (38.0494033, 23.7618983) -> Next: (38.0493966, 23.7618416) | Bearing: 261.47° | Orientation: West
# Current: (38.0493966, 23.7618416) -> Next: (38.0493816, 23.7617516) | Bearing: 258.05° | Orientation: West
# Current: (38.0493816, 23.7617516) -> Next: (38.0493449, 23.7616749) | Bearing: 238.72° | Orientation: Southwest
# Current: (38.0493449, 23.7616749) -> Next: (38.0493366, 23.7615916) | Bearing: 262.79° | Orientation: West
# Current: (38.0493366, 23.7615916) -> Next: (38.04936, 23.7616233) | Bearing: 46.85° | Orientation: Northeast
# Current: (38.04936, 23.7616233) -> Next: (38.0493316, 23.7615766) | Bearing: 232.32° | Orientation: Southwest
# Current: (38.0493316, 23.7615766) -> Next: (38.04932, 23.7615733) | Bearing: 192.63° | Orientation: South
# Current: (38.04932, 23.7615733) -> Next: (38.0492899, 23.7615833) | Bearing: 165.34° | Orientation: South
# Current: (38.0492899, 23.7615833) -> Next: (38.0492866, 23.7615566) | Bearing: 261.08° | Orientation: West
# Current: (38.0492866, 23.7615566) -> Next: (38.0492616, 23.7614666) | Bearing: 250.57° | Orientation: West
# Current: (38.0492616, 23.7614666) -> Next: (38.0493166, 23.7614683) | Bearing: 1.39° | Orientation: North
# Current: (38.0493166, 23.7614683) -> Next: (38.049435, 23.7615066) | Bearing: 14.29° | Orientation: North
# Current: (38.049435, 23.7615066) -> Next: (38.0494383, 23.7615283) | Bearing: 79.07° | Orientation: East
# Current: (38.0494383, 23.7615283) -> Next: (38.0495266, 23.76154) | Bearing: 5.96° | Orientation: North
# Current: (38.0495266, 23.76154) -> Next: (38.0495633, 23.76153) | Bearing: 347.89° | Orientation: North
# Current: (38.0495633, 23.76153) -> Next: (38.04963, 23.7615066) | Bearing: 344.56° | Orientation: North
# Current: (38.04963, 23.7615066) -> Next: (38.04966, 23.7614916) | Bearing: 338.51° | Orientation: North
# Current: (38.04966, 23.7614916) -> Next: (38.049705, 23.7614483) | Bearing: 322.85° | Orientation: Northwest
# Current: (38.049705, 23.7614483) -> Next: (38.0497249, 23.7614016) | Bearing: 298.42° | Orientation: Northwest
# Current: (38.0497249, 23.7614016) -> Next: (38.04975, 23.7613366) | Bearing: 296.12° | Orientation: Northwest
# Current: (38.04975, 23.7613366) -> Next: (38.0498116, 23.7613133) | Bearing: 343.41° | Orientation: North
# Current: (38.0498116, 23.7613133) -> Next: (38.0498616, 23.761265) | Bearing: 322.74° | Orientation: Northwest
# Current: (38.0498616, 23.761265) -> Next: (38.0499066, 23.761245) | Bearing: 340.71° | Orientation: North
# Current: (38.0499066, 23.761245) -> Next: (38.0499233, 23.7612249) | Bearing: 316.54° | Orientation: Northwest
# Current: (38.0499233, 23.7612249) -> Next: (38.0499333, 23.7611966) | Bearing: 294.17° | Orientation: Northwest
# Current: (38.0499333, 23.7611966) -> Next: (38.0499666, 23.76116) | Bearing: 319.12° | Orientation: Northwest
# Current: (38.0499666, 23.76116) -> Next: (38.0500166, 23.7611733) | Bearing: 11.83° | Orientation: North
# Current: (38.0500166, 23.7611733) -> Next: (38.0500716, 23.7611833) | Bearing: 8.15° | Orientation: North
# Current: (38.0500716, 23.7611833) -> Next: (38.0501133, 23.7611583) | Bearing: 334.73° | Orientation: Northwest
# Current: (38.0501133, 23.7611583) -> Next: (38.0501433, 23.7610883) | Bearing: 298.56° | Orientation: Northwest
# Current: (38.0501433, 23.7610883) -> Next: (38.050185, 23.7610216) | Bearing: 308.45° | Orientation: Northwest
# Current: (38.050185, 23.7610216) -> Next: (38.0501716, 23.760995) | Bearing: 237.39° | Orientation: Southwest
# Current: (38.0501716, 23.760995) -> Next: (38.0501416, 23.7609616) | Bearing: 221.24° | Orientation: Southwest
# Current: (38.0501416, 23.7609616) -> Next: (38.0501316, 23.7609433) | Bearing: 235.24° | Orientation: Southwest
# Current: (38.0501316, 23.7609433) -> Next: (38.0500916, 23.7608733) | Bearing: 234.03° | Orientation: Southwest
# Current: (38.0500916, 23.7608733) -> Next: (38.0501033, 23.7608033) | Bearing: 281.98° | Orientation: West
# Current: (38.0501033, 23.7608033) -> Next: (38.050095, 23.760765) | Bearing: 254.61° | Orientation: West
# Current: (38.050095, 23.760765) -> Next: (38.0501016, 23.7606916) | Bearing: 276.51° | Orientation: West
# Current: (38.0501016, 23.7606916) -> Next: (38.0501333, 23.7606216) | Bearing: 299.90° | Orientation: Northwest
# Current: (38.0501333, 23.7606216) -> Next: (38.0501383, 23.7605666) | Bearing: 276.59° | Orientation: West
# Current: (38.0501383, 23.7605666) -> Next: (38.0501766, 23.7606033) | Bearing: 37.04° | Orientation: Northeast
# Current: (38.0501766, 23.7606033) -> Next: (38.050275, 23.7607533) | Bearing: 50.20° | Orientation: Northeast
# Current: (38.050275, 23.7607533) -> Next: (38.0503816, 23.7608116) | Bearing: 23.30° | Orientation: Northeast
# Current: (38.0503816, 23.7608116) -> Next: (38.0504166, 23.7608399) | Bearing: 32.49° | Orientation: Northeast
# Current: (38.0504166, 23.7608399) -> Next: (38.05047, 23.7608083) | Bearing: 335.01° | Orientation: Northwest
# Current: (38.05047, 23.7608083) -> Next: (38.0505049, 23.7607866) | Bearing: 333.91° | Orientation: Northwest
# Current: (38.0505049, 23.7607866) -> Next: (38.0505416, 23.760765) | Bearing: 335.13° | Orientation: Northwest
# Current: (38.0505416, 23.760765) -> Next: (38.050545, 23.7606899) | Bearing: 273.29° | Orientation: West
# Current: (38.050545, 23.7606899) -> Next: (38.0505433, 23.7606483) | Bearing: 267.03° | Orientation: West
# Current: (38.0505433, 23.7606483) -> Next: (38.0505283, 23.7605866) | Bearing: 252.84° | Orientation: West
# Current: (38.0505283, 23.7605866) -> Next: (38.0505966, 23.7606366) | Bearing: 29.96° | Orientation: Northeast
# Current: (38.0505966, 23.7606366) -> Next: (38.0505616, 23.7605783) | Bearing: 232.68° | Orientation: Southwest
# Current: (38.0505616, 23.7605783) -> Next: (38.0504866, 23.7604666) | Bearing: 229.55° | Orientation: Southwest
# Current: (38.0504866, 23.7604666) -> Next: (38.0505083, 23.7604783) | Bearing: 23.01° | Orientation: Northeast
# Current: (38.0505083, 23.7604783) -> Next: (38.0504866, 23.7604433) | Bearing: 231.79° | Orientation: Southwest
# Current: (38.0504866, 23.7604433) -> Next: (38.0504633, 23.7604266) | Bearing: 209.44° | Orientation: Southwest
# Current: (38.0504633, 23.7604266) -> Next: (38.0504733, 23.7605066) | Bearing: 80.98° | Orientation: East
# Current: (38.0504733, 23.7605066) -> Next: (38.0504583, 23.7606766) | Bearing: 96.39° | Orientation: East
# Current: (38.0504583, 23.7606766) -> Next: (38.0504233, 23.760755) | Bearing: 119.55° | Orientation: Southeast
# Current: (38.0504233, 23.760755) -> Next: (38.05038, 23.7608333) | Bearing: 125.08° | Orientation: Southeast
# Current: (38.05038, 23.7608333) -> Next: (38.050335, 23.7608683) | Bearing: 148.51° | Orientation: Southeast
# Current: (38.050335, 23.7608683) -> Next: (38.050375, 23.7608483) | Bearing: 338.51° | Orientation: North
# Current: (38.050375, 23.7608483) -> Next: (38.0503416, 23.760815) | Bearing: 218.14° | Orientation: Southwest
# Current: (38.0503416, 23.760815) -> Next: (38.0503999, 23.7608399) | Bearing: 18.59° | Orientation: North
# Current: (38.0503999, 23.7608399) -> Next: (38.0504566, 23.7608933) | Bearing: 36.56° | Orientation: Northeast
# Current: (38.0504566, 23.7608933) -> Next: (38.0504866, 23.7609516) | Bearing: 56.84° | Orientation: Northeast
# Current: (38.0504866, 23.7609516) -> Next: (38.050525, 23.760955) | Bearing: 3.99° | Orientation: North
# Current: (38.050525, 23.760955) -> Next: (38.0505566, 23.7609316) | Bearing: 329.75° | Orientation: Northwest
# Current: (38.0505566, 23.7609316) -> Next: (38.0506166, 23.7609516) | Bearing: 14.71° | Orientation: North
# Current: (38.0506166, 23.7609516) -> Next: (38.050665, 23.76095) | Bearing: 358.51° | Orientation: North
# Current: (38.050665, 23.76095) -> Next: (38.0507149, 23.7609866) | Bearing: 30.01° | Orientation: Northeast
# Current: (38.0507149, 23.7609866) -> Next: (38.05076, 23.7610299) | Bearing: 37.09° | Orientation: Northeast
# Current: (38.05076, 23.7610299) -> Next: (38.0508116, 23.7610733) | Bearing: 33.52° | Orientation: Northeast
# Current: (38.0508116, 23.7610733) -> Next: (38.0508433, 23.7611183) | Bearing: 48.19° | Orientation: Northeast
# Current: (38.0508433, 23.7611183) -> Next: (38.0508016, 23.7611399) | Bearing: 157.81° | Orientation: South
# Current: (38.0508016, 23.7611399) -> Next: (38.0507716, 23.7611433) | Bearing: 174.90° | Orientation: South

# %% [markdown]
# Add <u>**orientation column for the 30 degrees turns</u>** to corresponding coordinates

# %%
def add_orientation_column(DATA_SORTED):
    # Function to calculate the bearing between two points
    def calculate_bearing(lat1, lon1, lat2, lon2):
        """
        Calculate the bearing between two points.
        Returns the bearing in degrees.
        """
        lat1_rad, lon1_rad = math.radians(lat1), math.radians(lon1)
        lat2_rad, lon2_rad = math.radians(lat2), math.radians(lon2)

        delta_lon = lon2_rad - lon1_rad
        x = math.sin(delta_lon) * math.cos(lat2_rad)
        y = math.cos(lat1_rad) * math.sin(lat2_rad) - math.sin(lat1_rad) * math.cos(lat2_rad) * math.cos(delta_lon)
        bearing = math.atan2(x, y)
        bearing_degrees = (math.degrees(bearing) + 360) % 360  # Normalize to 0-360
        return bearing_degrees

    # Function to get orientation from bearing
    def get_orientation(bearing):
        """
        Convert a bearing in degrees to a cardinal direction.
        """
        directions = ['North', 'Northeast', 'East', 'Southeast', 'South', 'Southwest', 'West', 'Northwest']
        idx = round(bearing / 45) % 8  # Divide by 45 degrees for 8 cardinal directions
        return directions[idx]

    # Add a new column "orientation"
    orientations = []

    # Loop through the DataFrame to calculate the bearing and orientation for each pair of consecutive coordinates
    for idx in range(len(DATA_SORTED) - 1):
        current_row = DATA_SORTED.iloc[idx]
        next_row = DATA_SORTED.iloc[idx + 1]
        
        # Calculate the bearing
        bearing = calculate_bearing(current_row['lat'], current_row['lng'], next_row['lat'], next_row['lng'])
        
        # Get the orientation from the bearing
        orientation = get_orientation(bearing)
        
        # Append the orientation to the list
        orientations.append(orientation)

    # For the last row, we can either leave the orientation empty or set it as "" since it has no "next" coordinate
    orientations.append("")

    # Add the "orientation" column to the DataFrame
    DATA_SORTED['orientation'] = orientations

    # Return the updated DataFrame
    return DATA_SORTED

# Assuming 'DATA_SORTED' is already defined as a DataFrame with columns 'lat' and 'lng'
DATA_SORTED = add_orientation_column(DATA_SORTED)

# Write the updated DataFrame to a CSV file
DATA_SORTED.to_csv(VEHICLE_15_PATH, index=False)

# Check the updated DataFrame
print(Fore.YELLOW + F"Updated DataFrame written to {VEHICLE_15_PATH}." + Style.RESET_ALL)
# Out:
# Updated DataFrame written to ../../DataSets/API_Responses/Vehicle_Data/Vehicle_15_response.csv.

# %% [markdown]
# Plot the months with the most data

# %%
# Assuming df is your DataFrame
df['dateOnlyStoredHuman'] = pd.to_datetime(df['dateOnlyStoredHuman'])

# Add a column for frequency (each entry is treated as one occurrence)
df['frequency'] = 1

# Group by 7-day intervals
df['frequency'] = df.groupby(
    pd.Grouper(key='dateOnlyStoredHuman', freq='7D', sort=True)
)['frequency'].sum()

# Reset index for plotting
df['frequency'].reset_index()

# Plotting
plt.bar(df['dateOnlyStoredHuman'], df['frequency'], width=5, align='center')  # Adjust width for better spacing
plt.title('Frequency of Dates (7-Day Intervals)')
plt.xlabel('Dates')
plt.ylabel('Frequency')
plt.yscale('log')  # Use a log scale if needed for better visualization
plt.minorticks_on()
plt.grid(visible=True, which='both', linestyle='--', linewidth=0.5)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping

plt.show()

# %% [markdown]
# Plot **velocities** of <u>1 day<u/>

# %%
def generate_all_days(file_path):
    """
    Generates a DataFrame containing all unique days in ISO format.

    Args: 
        file_path (str): The file's path.

    Returns:
        tuple: 
            - pd.DataFrame: Original data with date columns added.
            - pd.DataFrame: A DataFrame where each row contains a unique day in ISO format.
    """
    try:
        # Load the file into a DataFrame
        data = pd.read_csv(file_path)

        # Verify that the required columns exist
        if 'timeOnly' not in data.columns or 'dateStored' not in data.columns:
            raise KeyError("The file must contain 'timeOnly' and 'dateStored' columns.")

        # Convert the 'dateStored' column to datetime for filtering
        data['dateStoredHuman'] = pd.to_datetime(data['dateStored'], unit='ms')
        
        # Extract the date-only part in ISO format
        data['dateOnly'] = data['dateStoredHuman'].dt.date

        # Get unique dates and sort them
        unique_days = sorted(data['dateOnly'].unique())

        # Create a new DataFrame for the unique days
        days_df = pd.DataFrame(unique_days, columns=["Day"])
        days_df['Day'] = days_df['Day'].astype(str)  # Convert to ISO string format

        return data, days_df

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return pd.DataFrame(), pd.DataFrame(columns=["Day"])
    except KeyError as e:
        print(f"Error: Missing expected column in the file. {e}")
        return pd.DataFrame(), pd.DataFrame(columns=["Day"])
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return pd.DataFrame(), pd.DataFrame(columns=["Day"])


# Generate all days
data, df_all_days = generate_all_days(VEHICLE_15_PATH)

if not df_all_days.empty:
    single_day = df_all_days['Day'][0]  # Select the first day
    single_day_data = data[data['dateOnly'] == pd.to_datetime(single_day).date()]  # Filter data for the single day

    if not single_day_data.empty:
        # Extract velocity and time
        velocities = single_day_data['velocity'] if 'velocity' in single_day_data.columns else [0] * len(single_day_data)
        time_labels = single_day_data['timeOnly']
        orientations = single_day_data['orientation'] if 'orientation' in single_day_data.columns else [''] * len(single_day_data)
        
        # Plot the velocities for the single day
        plt.figure(figsize=(40, 30))
        plt.plot(time_labels, velocities, marker='o', linestyle='-', color='b')

        # Label the points with orientations
        for i, txt in enumerate(orientations):
            plt.text(time_labels[i], velocities[i], f'{txt}', ha='left', va='bottom', fontsize=9)

        plt.title(f"Velocities on {single_day}")
        plt.xlabel('Time (HH:MM:SS)')
        plt.ylabel('Velocity')
        plt.xticks(rotation=45)
        plt.grid(True)

        # Save the plot
        plot_filename = os.path.join(PLOT_FOLDER_PATH, f'{single_day}_velocities.png')
        
        print(f"Plot saved as {plot_filename}")

        # Show the plot
        plt.show()
    else:
        print(f"No data available for the selected day: {single_day}")
else:
    print("No days available in the data.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 75
#      72 plt.grid(True)
#      74 # Save the plot
# ---> 75 plot_filename = os.path.join(PLOT_FOLDER_PATH, f'{single_day}_velocities.png')
#      77 print(f"Plot saved as {plot_filename}")
#      79 # Show the plot
#
# NameError: name 'PLOT_FOLDER_PATH' is not defined

# %% [markdown]
# Plot <u>velocities, orientations</u> **on** <u>coordinates</u>>

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Latitude')
plt.ylabel('Longitude')
# Turn off offset notation
plt.gca().ticklabel_format(useOffset=False)
plt.grid()
scatter = plt.scatter(lat_clmn, long_clmn, c=df['velocity'], cmap='viridis', s=100, edgecolors='k')
#* Add color bar
colorbar = plt.colorbar(scatter)
colorbar.set_label('Velocities')

plt.show()

# %%
def get_one_day(start_date, start_time, df):
    """
    Calculates time differences from a starting datetime using a DataFrame with separate date and time columns.
    
    Args:
        start_date (str): Starting date in "YYYY-MM-DD" format.
        start_time (str): Starting time in "HH:MM:SS" format.
        df (pd.DataFrame): DataFrame containing 'date' and 'time' columns.
    
    Returns:
        pd.DataFrame: DataFrame with calculated datetime and time differences.
        pd.DataFrame: Filtered DataFrame with differences within 5 minutes.
    """
    # Combine start date and time into a single datetime object
    start_datetime = datetime.strptime(f"{start_date} {start_time}", "%Y-%m-%d %H:%M:%S")

    # Function to calculate time differences in minutes, accounting for day transitions
    def time_diff_with_date(row, start_datetime):
        # Combine target date and time into a datetime object
        target_datetime = datetime.strptime(f"{row['date']} {row['time']}", "%Y-%m-%d %H:%M:%S")
        
        # Calculate the time difference in minutes
        time_diff_minutes = (target_datetime - start_datetime).total_seconds() / 60
        return target_datetime, time_diff_minutes

    # Apply the function to calculate differences for each row
    results = df.apply(lambda row: time_diff_with_date(row, start_datetime), axis=1)
    
    # Unpack results and add to DataFrame
    df["calculated_datetime"] = [res[0] for res in results]
    df["time_diff_minutes"] = [res[1] for res in results]

    # Filter rows with time differences within 5 minutes
    filtered_df = df[df["time_diff_minutes"].abs() <= 5]

    return df, filtered_df


filtered_df = merged_dfs.loc(merged_dfs['vehicleId'] == 15)
start_date = filtered_df['dateOnlyStoredHuman'][0]
start_time = filtered_df['timeOnly'][0]

full_df, filtered_df = get_one_day(start_date, start_time, filtered_df)

print("Full DataFrame:")
print(full_df)
print("\nFiltered DataFrame (5-minute difference):")
print(filtered_df)
